# %% [markdown]
# # Leios simulation analysis at tag `leios-2025w31`

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Load packages

# %%
suppressMessages({
    require(data.table, quietly=TRUE)
    require(ggplot2, quietly=TRUE)
    require(magrittr, quietly=TRUE)
})

# %% [markdown]
# ### Define utility functions

# %%
sort_factors <- function(fs, ascending=TRUE) {
    xs <- fs[as.numeric(sub(" .*$", "", fs)) %>% order]
    if (ascending)
        xs
    else
        rev(xs)
}

# %% [markdown]
# ## Experiment: Haskell vs Rust for Linear Leios without modeling transactions

# %% [markdown]
# ### Analysis of lifecycles and efficiencies

# %% [markdown]
# #### Read the lifecycle results

# %%
if (file.exists("results/lifecycle.Rdata")) {
    load(file="results/lifecycle.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    lifecycle <- fread("results/lifecycle.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(lifecycle, sampleSize, file="results/lifecycle.R")
}
setnames(lifecycle, old="Kind", new="Message")
lifecycle[, `Stage length`:=factor(`Stage length`, levels=sort_factors(lifecycle[, unique(`Stage length`)]))]
lifecycle %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#    Simulator     Variant                Network      Bandwidth
#  Haskell: 45   linear:337   topo-default-100:337   50 Mb/s:337
#  Rust   :292
#
#
#
#
#
#        Stage length         EB rate      Max EB size       Tx size
#  8 slot/stage:337   2.5 EB/stage:337   10 MB/EB:337   1500 B/Tx:337
#
#
#
#
#
#
#         Throughput   Tx start [s]  Tx stop [s]   Sim stop [s]  Message
#  0.150 TxMB/s:337   Min.   :0     Min.   :900   Min.   :1200   EB:118
#                     1st Qu.:0     1st Qu.:900   1st Qu.:1200   RB: 73
#                     Median :0     Median :900   Median :1200   TX:146
#                     Mean   :0     Mean   :900   Mean   :1200
#                     3rd Qu.:0     3rd Qu.:900   3rd Qu.:1200
#                     Max.   :0     Max.   :900   Max.   :1200
#
#            Item        Size [B]          References      Created [s]
#  1012-node-82:  2   Min.   :       0   Min.   :0.0000   Min.   :   9.13
#  102-node-33 :  2   1st Qu.:    1024   1st Qu.:0.0000   1st Qu.: 389.13
#  1037-node-94:  2   Median :10000000   Median :0.0000   Median : 652.13
#  1042-node-68:  2   Mean   : 5667970   Mean   :0.4332   Mean   : 641.58
#  1068-node-59:  2   3rd Qu.:10000240   3rd Qu.:1.0000   3rd Qu.: 921.08
#  1074-node-17:  2   Max.   :10000304   Max.   :1.0000   Max.   :1193.08
#  (Other)     :325
#  To IB [s]        To EB [s]       To RB [s]        In RB [s]
#  Mode:logical   Min.   :  29.07   Mode:logical   Min.   :  29.07
#  NA's:337       1st Qu.: 394.07   NA's:337       1st Qu.: 394.07
#                 Median : 661.08                  Median : 661.08
#                 Mean   : 646.35                  Mean   : 646.35
#                 3rd Qu.: 924.08                  3rd Qu.: 924.08
#                 Max.   :1193.08                  Max.   :1193.08
#                 NA's   :264                      NA's   :264

# %%
label <- lifecycle[, unique(paste(`Variant`, `Network`, `Bandwidth`, `Stage length`, `EB rate`, `Max EB size`, `Tx size`, `Throughput`, sep=", "))]

# %%
fixed <- c("Variant", "Network", "Bandwidth", "Stage length", "EB rate", "Max EB size", "Tx size", "Throughput")

# %%
varied <- c("Simulator")

# %%
facet_varied <- function(scales="free_y", wide=FALSE) {
    if (wide)
        facet_grid(. ~ `Simulator`, scales=scales)
    else
        facet_grid(`Simulator` ~ ., scales=scales)
}

# %%
simFinish <- lifecycle[, unique(`Sim stop [s]`)]

# %% [markdown]
# #### Size of persisted data

# %%
ggplot(
    lifecycle[`Message` != "TX",
        .(`Size [kB/s]`=sum(`Size [B]`)/1e3/600),
        c(varied, "Message")
    ],
    aes(x=!!sym(varied), y=`Size [kB/s]`, fill=`Message`)
) + geom_bar(stat="identity") +
    ggtitle("Size of diffused data", subtitle=label)
# Out:
# plot without title

# %%
ggsave("plots/sizes.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Release memory

# %%
rm(lifecycle)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  916454 49.0 1775612    94.9 1354928  72.4
# Vcells 1682875 12.9 8388608    64.0 2695875  20.6

# %% [markdown]
# ### Resource usage

# %%
if (file.exists("results/resources.Rdata")) {
    load(file="results/resources.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    resources <- fread("results/resources.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(resources, file="results/resources.Rdata")
}
resources[, `Stage length`:=factor(`Stage length`, levels=sort_factors(resources[, unique(`Stage length`)]))]
resources %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#    Simulator     Variant                Network      Bandwidth
#  Haskell:100   linear:200   topo-default-100:200   50 Mb/s:200
#  Rust   :100
#
#
#
#
#
#        Stage length         EB rate      Max EB size       Tx size
#  8 slot/stage:200   2.5 EB/stage:200   10 MB/EB:200   1500 B/Tx:200
#
#
#
#
#
#
#         Throughput   Tx start [s]  Tx stop [s]   Sim stop [s]       Node
#  0.150 TxMB/s:200   Min.   :0     Min.   :900   Min.   :1200   node-0 :  2
#                     1st Qu.:0     1st Qu.:900   1st Qu.:1200   node-1 :  2
#                     Median :0     Median :900   Median :1200   node-10:  2
#                     Mean   :0     Mean   :900   Mean   :1200   node-11:  2
#                     3rd Qu.:0     3rd Qu.:900   3rd Qu.:1200   node-12:  2
#                     Max.   :0     Max.   :900   Max.   :1200   node-13:  2
#                                                                (Other):188
#    Egress [B]        Disk [B]        Total CPU [s]    Maximum CPU [s/s]
#  Min.   :   553   Min.   :       0   Min.   : 56.16   Min.   : 5.050
#  1st Qu.:  5865   1st Qu.:       0   1st Qu.: 75.00   1st Qu.: 5.051
#  Median : 16606   Median :       0   Median :216.79   Median : 5.079
#  Mean   : 65159   Mean   : 5900760   Mean   :214.36   Mean   : 6.750
#  3rd Qu.:118191   3rd Qu.:10001329   3rd Qu.:353.03   3rd Qu.:10.200
#  Max.   :299738   Max.   :40005056   Max.   :363.73   Max.   :15.300

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `Nodal egress [Mb/s]`=8*`Egress [B]`/simFinish/1e6)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`Nodal egress [Mb/s]`)
) +
    geom_violin() +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("Network", label)
# Out:
# plot without title

# %%
ggsave("plots/network.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `1-Second peak CPU [vCPU⋅s/s]`=`Maximum CPU [s/s]`)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`1-Second peak CPU [vCPU⋅s/s]`)
) +
    geom_boxplot() +
    ylim(0, NA) +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("1-Second Peak CPU", label)
# Out:
# plot without title

# %%
ggsave("plots/cpu-peak.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `Mean CPU [vCPU⋅s/s]`=`Total CPU [s]`/simFinish)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`Mean CPU [vCPU⋅s/s]`)
) +
    geom_boxplot() +
    ylim(0, NA) +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("Mean CPU", label)
# Out:
# plot without title

# %%
ggsave("plots/cpu-mean.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Release memory

# %%
rm(resources)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  976644 52.2 1775612    94.9 1775612  94.9
# Vcells 1784262 13.7 8388608    64.0 3090883  23.6

# %% [markdown]
# ### Receipt of messages

# %% [markdown]
# #### Read results

# %%
if (file.exists("results/receipts.Rdata")) {
    load("results/receipts.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    receipts <- fread("results/receipts.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(receipts, file="results/receipts.Rdata")
}
setnames(receipts, old="Kind", new="Message")
receipts[, `Stage length`:=factor(`Stage length`, levels=sort_factors(receipts[, unique(`Stage length`)]))]
receipts %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#    Simulator       Variant                  Network        Bandwidth
#  Haskell:12795   linear:38249   topo-default-100:38249   50 Mb/s:38249
#  Rust   :25454
#
#
#
#
#
#        Stage length           EB rate        Max EB size         Tx size
#  8 slot/stage:38249   2.5 EB/stage:38249   10 MB/EB:38249   1500 B/Tx:38249
#
#
#
#
#
#
#         Throughput     Tx start [s]  Tx stop [s]   Sim stop [s]  Message
#  0.150 TxMB/s:38249   Min.   :0     Min.   :900   Min.   :1200   EB:10898
#                       1st Qu.:0     1st Qu.:900   1st Qu.:1200   RB:15768
#                       Median :0     Median :900   Median :1200   VT:11583
#                       Mean   :0     Mean   :900   Mean   :1200
#                       3rd Qu.:0     3rd Qu.:900   3rd Qu.:1200
#                       Max.   :0     Max.   :900   Max.   :1200
#
#            Item          Producer     Generated [s]         Size [B]
#  930-node-16 :  370   node-33: 1452   Min.   :   9.001   Min.   :     105
#  1037-node-94:  366   node-21: 1362   1st Qu.: 375.130   1st Qu.:     105
#  347-node-39 :  366   node-14: 1247   Median : 649.001   Median :    1024
#  538-node-53 :  366   node-47: 1080   Mean   : 633.272   Mean   : 2849754
#  924-node-53 :  366   node-88: 1019   3rd Qu.: 906.001   3rd Qu.:10000240
#  1115-node-22:  365   node-79: 1017   Max.   :1193.075   Max.   :10000304
#  (Other)     :36050   (Other):31072
#    Recipient      Received [s]       Elapsed [s]
#  node-91:  407   Min.   :   9.018   Min.   : 0.00625
#  node-2 :  404   1st Qu.: 395.151   1st Qu.: 0.91710
#  node-51:  404   Median : 659.655   Median : 1.78280
#  node-0 :  400   Mean   : 642.311   Mean   : 9.03921
#  node-44:  398   3rd Qu.: 917.280   3rd Qu.:20.08420
#  node-60:  398   Max.   :1199.792   Max.   :50.20560
#  (Other):35838

# %%
kinds <- receipts[, unique(`Message`) %>% sort]
kinds
# Out:
# [1] EB RB VT
# Levels: EB RB VT

# %% [markdown]
# #### Arrival histograms

# %% [markdown]
# ##### Compare the distributions of elapsed times

# %%
arrivalDelayHistogram <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[, .(`Varied`, `Network`, `Elapsed [s]`, `Minute created`=factor(floor(`Generated [s]`/60)))],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Elapsed [s]`, fill=`Minute created`)
    ) +
        geom_histogram(binwidth=0.1) +
        facet_varied(scales=scales) +
        xlab("Time from generation to receipt at node [s]") +
        ylab("Number received") +
        ggtitle(title, subtitle=label) +
        theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
for (k in kinds)
    arrivalDelayHistogram(
        receipts[`Message` == k],
        paste("Arrival delay for", k),
        scales="free_y",
        outfiles=paste0("plots/elapsed-", k, ".png")
    ) %>% print
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# #### Bandwidth usagefacet_varied

# %% [markdown]
# ##### Total network bandwidth

# %%
totalBandwidthPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Gb]`=8*sum(`Size [B]`, rm.na=TRUE)/1e9/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Gb]`, fill=`Message`)
    ) +
        geom_area() +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Total network ingress [Gb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
totalBandwidthPlot(
    receipts,
    "Total bandwidth",
    scales="free_y",
    outfiles=paste0("plots/ingress-total-area.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Bandwidth usage per node

# %%
nodeCount <- receipts[, length(unique(`Recipient`))]
nodeCount
# Out:
# [1] 100

# %%
meanNodalIngressPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Mb/node]`=8*sum(`Size [B]`)/1e6/ifelse(`Network`=="topology-v1",10000,750)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Mb/node]`, fill=`Message`)
    ) +
        geom_area() +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Mean network ingress among nodes [Mb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanNodalIngressPlot(
    receipts, 
    "Mean nodal ingress",
    outfiles=paste0("plots/ingress-average-area.png")
)
# Out:
# plot without title

# %%
peakNodalIngressPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Mb]`=8*sum(`Size [B]`, rm.na=TRUE)/1e6/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`, `Recipient`)
            ][,
                .(`Size [Mb]`=max(`Size [Mb]`)),
                by=.(`Varied`, `Network`, `Slot`, `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Mb]`, color=`Message`)
    ) +
        geom_point(size=0.5) +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Maximum network ingress among nodes [Mb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakNodalIngressPlot(
    receipts, 
    "Peak nodal ingress",
    outfiles=paste0("plots/ingress-peak-point.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Release memory

# %%
rm(receipts)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells  994245 53.1 2170734    116.0 2170734  116.0
# Vcells 2287191 17.5 8393588     64.1 8393588   64.1

# %% [markdown]
# ### CPU usage

# %% [markdown]
# #### Read results

# %%
if (file.exists("results/cpus.Rdata")) {
    load(file="results/cpus.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    cpus <- fread("results/cpus.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(cpus, file="results/cpus.Rdata")
}
cpus[, `Stage length`:=factor(`Stage length`, levels=sort_factors(cpus[, unique(`Stage length`)]))]
cpus %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#    Simulator       Variant                  Network        Bandwidth
#  Haskell:52489   linear:92204   topo-default-100:92204   50 Mb/s:92204
#  Rust   :39715
#
#
#
#
#
#        Stage length           EB rate        Max EB size         Tx size
#  8 slot/stage:92204   2.5 EB/stage:92204   10 MB/EB:92204   1500 B/Tx:92204
#
#
#
#
#
#
#         Throughput     Tx start [s]  Tx stop [s]   Sim stop [s]
#  0.150 TxMB/s:92204   Min.   :0     Min.   :900   Min.   :1200
#                       1st Qu.:0     1st Qu.:900   1st Qu.:1200
#                       Median :0     Median :900   Median :1200
#                       Mean   :0     Mean   :900   Mean   :1200
#                       3rd Qu.:0     3rd Qu.:900   3rd Qu.:1200
#                       Max.   :0     Max.   :900   Max.   :1200
#
#       Slot             Node            Task        Duration [s]
#  Min.   :   9.0   node-2 :  963   ValRH  :49372   Min.   :0.000
#  1st Qu.: 376.0   node-91:  961   ValRB  :15768   1st Qu.:0.001
#  Median : 649.0   node-51:  960   ValVote:11583   Median :0.001
#  Mean   : 628.8   node-0 :  959   ValEB  : 8295   Mean   :0.465
#  3rd Qu.: 902.0   node-66:  957   ValEH  : 6833   3rd Qu.:0.050
#  Max.   :1199.0   node-60:  955   GenRB  :  191   Max.   :5.050
#                   (Other):86449   (Other):  162

# %%
cpusNode <-
    substitute(
        cpus[
            ,
            .(`Duration [s]`=sum(`Duration [s]`)),
            by=.(`Varied`, `Network`, `Node`, `Slot`)
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval

# %%
nodeCount <- cpusNode[, length(unique(`Node`))]
nodeCount
# Out:
# [1] 100

# %% [markdown]
# #### Peak CPU usage

# %% [markdown]
# ##### Histogram

# %%
peakCpuHistogram <- function(cs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*max(`Duration [s]`)),
                by=.(`Varied`, `Network`, `Slot`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Duration [%]`)
    ) +
        geom_histogram(binwidth=10) +
        facet_varied(scales=scales) +
        xlab("Peak CPU load [%]") +
        ylab("Number of slots") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakCpuHistogram(
    cpusNode, 
    "Peak CPU load among all nodes",
    scales="free_y",
    outfiles=paste0("plots/cpu-peak-histogram.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Time series

# %%
peakCpuTimeseries <- function(cs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*mean(`Duration [s]`)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Duration [%]`)) +
        geom_line() +
        facet_varied(scale=scales) +
        xlab("Slot") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakCpuTimeseries(
    cpusNode,
    "Peak CPU load among all nodes",
    outfiles=paste0("plots/cpu-peak-timeseries.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Mean CPU usage

# %% [markdown]
# ##### Histogram

# %%
meanCpuHistogram <- function(cs, nodeSeconds, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*sum(`Duration [s]`)/nodeSeconds/ifelse(`Network` == "topology-v1", 10000, 750)),
                by=.(`Varied`, `Network`, `Task`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x="", fill=`Task`, y=`Duration [%]`)) +
        geom_bar(stat = "identity") +
        facet_varied(wide=TRUE, scales=scales) +
        xlab("") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanCpuHistogram(
    cpus,
    simFinish * sampleSize, 
    "Mean CPU load among all nodes", 
    scales="free_y",
    outfiles=paste0("plots/cpu-mean-histogram.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Time series

# %%
meanCpuTimeseries <- function(cs, nodeSeconds, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*sum(`Duration [s]`)/nodeSeconds/ifelse(`Network`=="topology-v1",10000,750)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`, `Task`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Duration [%]`, color=`Task`)
    ) +
        geom_point(size=0.25, alpha=0.75) +
        facet_varied(scales=scales) +
        scale_y_sqrt() +
        xlab("Slot") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanCpuTimeseries(
    cpus, 
    sampleSize, 
    "Mean CPU load among all nodes",
    outfiles=paste0("plots/cpu-mean-timeseries.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Release memory

# %%
rm(cpus, cpusNode)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells 1000183 53.5 2170734    116.0 2170734  116.0
# Vcells 2624391 20.1 8393588     64.1 8393588   64.1

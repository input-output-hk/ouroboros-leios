# %% [markdown]
# # Leios simulation analysis at tag `leios-2025w31`

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Load packages

# %%
suppressMessages({
    require(data.table, quietly=TRUE)
    require(ggplot2, quietly=TRUE)
    require(magrittr, quietly=TRUE)
})

# %% [markdown]
# ### Define utility functions

# %%
sort_factors <- function(fs, ascending=TRUE) {
    xs <- fs[as.numeric(sub(" .*$", "", fs)) %>% order]
    if (ascending)
        xs
    else
        rev(xs)
}

# %% [markdown]
# ## Experiment: varying transaction validation time

# %% [markdown]
# ### Context
#
# Although there is considerable variability, the longest-running Plutus transactions allowed on `mainnnet` (10e9 execution-unit steps) take approximately 15 milliseconds for their phase 2 validation.
#
# ![Plutus steps vs phase 1 & 2 validation in blocks](steps-time.png)
#
# The following experiment varies the validation time for transactions in the Leios simulation.
#
# | Tx validation in simulator [ms/tx] | Approximate Plutus execution steps | Plutus steps relative to mainnet limit |
# |-----------------------------------:|-----------------------------------:|---------------------------------------:|
# |                                  1 |                               0.7G |                                     7% |
# |                                  3 |                               2.0G |                                    20% |
# |                                 10 |                               6.7G |                                    67% |
# |                                 30 |                              20.0G |                                   200% |
# |                                100 |                              66.7G |                                   667% |

# %% [markdown]
# ### Analysis of lifecycles and efficiencies

# %% [markdown]
# #### Read the lifecycle results

# %%
if (file.exists("results/lifecycle.Rdata")) {
    load(file="results/lifecycle.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    lifecycle <- fread("results/lifecycle.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(lifecycle, sampleSize, file="results/lifecycle.R")
}
setnames(lifecycle, old="Kind", new="Message")
lifecycle[, `Tx validation`:=factor(`Tx validation`, levels=sort_factors(lifecycle[, unique(`Tx validation`)]))]
lifecycle %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#  Simulator                          Variant              Network
#  Rust:450601   linear-with-tx-references:450601   topology-v2:450601
#
#
#
#
#
#
#    Bandwidth            Stage length            EB rate         Max EB size
#  50 Mb/s:450601   8 slot/stage:450601   2.5 EB/stage:450601   10 MB/EB:450601
#
#
#
#
#
#
#       Tx size              Throughput      Tx start [s]  Tx stop [s]
#  1500 B/Tx:450601   0.150 TxMB/s:450601   Min.   :60    Min.   :960
#                                           1st Qu.:60    1st Qu.:960
#                                           Median :60    Median :960
#                                           Mean   :60    Mean   :960
#                                           3rd Qu.:60    3rd Qu.:960
#                                           Max.   :60    Max.   :960
#
#   Sim stop [s]       Tx validation   Message               Item
#  Min.   :1200   1.00 ms/Tx  :90115   EB:   298   105-node-598:    10
#  1st Qu.:1200   3.00 ms/Tx  :90115   RB:   298   131-node-573:    10
#  Median :1200   10.00 ms/Tx :90115   TX:450005   177-node-149:    10
#  Mean   :1200   30.00 ms/Tx :90115               20-node-220 :    10
#  3rd Qu.:1200   100.00 ms/Tx:90141               26-node-95  :    10
#  Max.   :1200                                    296-node-99 :    10
#                                                  (Other)     :450541
#     Size [B]        References     Created [s]      To IB [s]
#  Min.   :   240   Min.   : 0.00   Min.   :  20.07   Mode:logical
#  1st Qu.:  1500   1st Qu.: 1.00   1st Qu.: 285.08   NA's:450601
#  Median :  1500   Median : 1.00   Median : 510.18
#  Mean   :  1625   Mean   : 2.47   Mean   : 510.16
#  3rd Qu.:  1500   3rd Qu.: 2.00   3rd Qu.: 735.22
#  Max.   :213552   Max.   :55.00   Max.   :1194.36
#
#    To EB [s]         To RB [s]         In RB [s]
#  Min.   :  65.08   Min.   :  54.08   Min.   :  65.1
#  1st Qu.: 287.08   1st Qu.: 383.08   1st Qu.: 383.1
#  Median : 518.08   Median : 552.08   Median : 576.1
#  Mean   : 526.62   Mean   : 572.66   Mean   : 569.4
#  3rd Qu.: 749.08   3rd Qu.: 767.08   3rd Qu.: 812.1
#  Max.   :1095.95   Max.   :1171.08   Max.   :1194.4
#  NA's   :76059     NA's   :101036    NA's   :439382

# %%
label <- lifecycle[, unique(paste(`Simulator`, `Variant`, `Network`, `Bandwidth`, `Stage length`, `EB rate`, `Max EB size`, `Tx size`, `Throughput`, "6 vCPU/node", sep=", "))]
label
# Out:
# [1] "Rust, linear-with-tx-references, topology-v2, 50 Mb/s, 8 slot/stage, 2.5 EB/stage, 10 MB/EB, 1500 B/Tx, 0.150 TxMB/s, 6 vCPU/node"

# %%
fixed <- c("Simulator", "Variant", "Network", "Bandwidth", "Stage length", "EB rate", "Max EB size", "Tx size", "Throughput")

# %%
varied <- c("Tx validation")

# %%
facet_varied <- function(scales="free_y", wide=FALSE) {
    if (wide)
        facet_grid(. ~ `Tx validation`, scales=scales)
    else
        facet_grid(`Tx validation` ~ ., scales=scales)
}

# %% [markdown]
# #### Range of transaction injection

# %%
txFirst <- lifecycle[, median(`Tx start [s]`)]
txLast <- lifecycle[, median(`Tx stop [s]`)]
txWindow <- txLast - txFirst
simFinish <- lifecycle[, median(`Sim stop [s]`)]

# %%
ggplot(lifecycle, aes(x=`Created [s]`)) +
    geom_histogram(binwidth=5, fill="lightgray") +
    geom_vline(xintercept=txFirst, color="blue") +
    geom_vline(xintercept=txLast, color="red") +
    ylab("Number of Transactions") +
    ggtitle("Time range of Transactions", label)
# Out:
# plot without title

# %% [markdown]
# #### Actual TPS

# %%
dtmp <- lifecycle[
    `Message` == "TX" & `Created [s]` >= txFirst & `Created [s]` <= txLast, 
    .(
        `Demand [tx/s]`=.N/txWindow
    ),
    c(fixed, varied)
]
setorderv(dtmp, varied)
dtmp
# Out:
#   Simulator Variant                   Network     Bandwidth Stage length
# 1 Rust      linear-with-tx-references topology-v2 50 Mb/s   8 slot/stage
# 2 Rust      linear-with-tx-references topology-v2 50 Mb/s   8 slot/stage
# 3 Rust      linear-with-tx-references topology-v2 50 Mb/s   8 slot/stage
# 4 Rust      linear-with-tx-references topology-v2 50 Mb/s   8 slot/stage
# 5 Rust      linear-with-tx-references topology-v2 50 Mb/s   8 slot/stage
#   EB rate      Max EB size Tx size   Throughput   Tx validation Demand [tx/s]
# 1 2.5 EB/stage 10 MB/EB    1500 B/Tx 0.150 TxMB/s 1.00 ms/Tx    100.0000
# 2 2.5 EB/stage 10 MB/EB    1500 B/Tx 0.150 TxMB/s 3.00 ms/Tx    100.0011
# 3 2.5 EB/stage 10 MB/EB    1500 B/Tx 0.150 TxMB/s 10.00 ms/Tx   100.0011
# 4 2.5 EB/stage 10 MB/EB    1500 B/Tx 0.150 TxMB/s 30.00 ms/Tx   100.0000
# 5 2.5 EB/stage 10 MB/EB    1500 B/Tx 0.150 TxMB/s 100.00 ms/Tx  100.0011

# %% [markdown]
# #### Size of persisted data

# %%
ggplot(
    lifecycle[,
        .(`Size [kB/s]`=sum(`Size [B]`)/1e3/600),
        c(varied, "Message")
    ],
    aes(x=!!sym(varied), y=`Size [kB/s]`, fill=`Message`)
) + geom_bar(stat="identity") +
    ggtitle("Size of diffused data", subtitle=label)
# Out:
# plot without title

# %%
ggsave("plots/sizes.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Spatial efficiency

# %%
dtmp <- lifecycle[
        `Message` == "TX", 
        .(`Tx size [B]`=sum(ifelse(is.na(`To RB [s]`) & is.na(`In RB [s]`), 0, 1.0 * `Size [B]`))),
        varied
    ][
        lifecycle[
            , 
            .(`Non-tx size [B]`=sum(as.numeric((`Variant` != "linear" & `Message` == "TX" | `Message` == "EB" | `Message` == "RB") * `Size [B]`))), 
            varied
        ],
        on=varied
    ][, .(`Space efficiency [%]`=100*`Tx size [B]`/`Non-tx size [B]`), varied]
setorderv(dtmp, varied)
dtmp
# Out:
#   Tx validation Space efficiency [%]
# 1 1.00 ms/Tx    93.3764491
# 2 3.00 ms/Tx    93.3753744
# 3 10.00 ms/Tx   93.3747337
# 4 30.00 ms/Tx   93.3752504
# 5 100.00 ms/Tx   0.6415534

# %%
ggplot(
    lifecycle[
        `Message` == "TX", 
        .(`Tx size [B]`=sum(ifelse(is.na(`To RB [s]`) & is.na(`In RB [s]`), 0, 1.0 * `Size [B]`))),
        varied
    ][
        lifecycle[
            `Message` != "VT", 
            .(`Non-tx size [B]`=sum(as.numeric((`Variant` != "linear" & `Message` == "TX" | `Message` == "EB" | `Message` == "RB") * `Size [B]`))), 
            varied
        ],
        on=varied
    ][, .(`Space efficiency [%]`=100*`Tx size [B]`/`Non-tx size [B]`), varied],
    aes(x=!!sym(varied), y=`Space efficiency [%]`)
) +
    geom_bar(stat="identity") +
    ylim(0, 100) +
    ggtitle("Spatial efficiency (size of txs on ledger / size of non-tx persisted data)", label)
# Out:
# plot without title

# %%
ggsave("plots/spatial-efficiency.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Time to reach the EB

# %%
dtmp <- lifecycle[
        `Message` == "TX" & 
        !is.na(`To EB [s]`) &
        `Created [s]` >= txFirst & `Created [s]` <= txLast, 
        .(`Time to reach EB [s]`=mean(`To EB [s]`-`Created [s]`)), 
        varied
    ]
setorderv(dtmp, varied)
dtmp
# Out:
#   Tx validation Time to reach EB [s]
# 1 1.00 ms/Tx     22.74536
# 2 3.00 ms/Tx     22.77034
# 3 10.00 ms/Tx    22.79380
# 4 30.00 ms/Tx    22.88407
# 5 100.00 ms/Tx  260.38949

# %%
ggplot(
    substitute(
        lifecycle[
            `Message` == "TX" & 
            !is.na(`To EB [s]`) &
            `Created [s]` >= txFirst & `Created [s]` < txLast, 
            .(`Time to reach EB [s]`=(`To EB [s]`-`Created [s]`)), 
            .(`Varied`, `Minute created`=factor(floor(`Created [s]`/60)))
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Time to reach EB [s]`, fill=`Minute created`)
) + geom_histogram(bins=50, position="stack") +
    facet_varied() +
    xlab("Time for transaction to reach EB [s]") +
    ylab("Number of items") +
    ggtitle("Time for transaction to reach an EB", label) +
    theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
# Out:
# plot without title

# %%
ggsave("plots/reach-eb-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Time to reach the ledger

# %%
dtmp <- lifecycle[
        `Message` == "TX" & 
        !is.na(`To RB [s]`) &
        `Created [s]` >= txFirst & `Created [s]` <= txLast, 
        .(`Time to reach ledger [s]`=mean(`To RB [s]`-`Created [s]`)), 
        varied
    ]
setorderv(dtmp, varied)
dtmp
# Out:
#   Tx validation Time to reach ledger [s]
# 1 1.00 ms/Tx    63.14496
# 2 3.00 ms/Tx    63.16366
# 3 10.00 ms/Tx   63.18651
# 4 30.00 ms/Tx   63.27119

# %%
ggplot(
    substitute(
        lifecycle[
            `Message` == "TX" & 
            !is.na(`To RB [s]`) &
            `Created [s]` >= txFirst & `Created [s]` < txLast, 
            .(`Time to reach ledger [s]`=`To RB [s]`-`Created [s]`), 
            .(`Varied`, `Minute created`=factor(floor(`Created [s]`/60)))
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Time to reach ledger [s]`, fill=`Minute created`)
) + geom_histogram(bins=50) +
    facet_varied() +
    xlab("Time for transaction to reach ledger [s]") +
    ylab("Number of items") +
    ggtitle("Time for transaction to reach the ledger", label) +
    theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
# Out:
# plot without title

# %%
ggsave("plots/reach-rb-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Number of references
#
# A *reference* is one of the following:
#
# - A transaction is included in an IB.
# - An IB is referenced by an EB.
# - An EB is referenced by another EB.
#
# In an efficient Leios, the number of references for each data item would be one.
#
# - *Zero references* indicates that the item was not used.
# - *Two or more references* indicates that duplication has occurred.

# %%
ggplot(
    lifecycle[
        `Message` == "EB",
        .(`References`),
        varied
    ], 
    aes(x=`References`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
#   scale_x_sqrt() +
    ylab("Number of EB") +
    ggtitle("Number of EB references (0 = not used, 2+ = duplicated)", label)
# Out:
# plot without title

# %%
ggsave("plots/references-tx.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    lifecycle[
        `Message` == "TX",
        .(`References`),
        varied
    ], 
    aes(x=`References`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
    ylab("Number of TX") +
    ggtitle("Number of TX references (0 = not used, 2+ = duplicated)", label)
# Out:
# plot without title

# %%
ggsave("plots/references-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Temporal efficiency

# %%
toElapsed <- function(created, toRb, inRb) {
    if (!is.na(toRb))
        toRb - created
    else if (!is.na(inRb))
        inRb - created
    else
        as.numeric(NA)
}

# %%
outcomes <- lifecycle[
    `Message` == "TX",
    .(
        `Submitted [minute]`=factor(floor(`Created [s]`/60)), 
        `Time to reach ledger [s]`=mapply(toElapsed, `Created [s]`, `To RB [s]`, `In RB [s]`)
    ),
    varied
]

# %%
totals <- substitute(
    outcomes[
        , 
        .(`Total`=.N, `Lost`=sum(is.na(`Time to reach ledger [s]`))), 
        .(`Varied`, `Submitted [minute]`)
    ],
    env=list(`Varied`=sym(varied))
) %>% eval

# %% [markdown]
# #### Transactions reaching the ledger

# %%
ggplot(
    substitute(
        melt(
            totals[, .(`On ledger`=1-`Lost`/`Total`, `Lost`=`Lost`/`Total`), .(`Varied`, `Submitted [minute]`)],
            id.vars=c(varied, "Submitted [minute]"),
            variable.name="Outcome",
            value.name="Fraction"
        )[`Submitted [minute]` != 6, .(
            `Varied`,
            `Submitted [minute]`, 
            `Outcome`=factor(`Outcome`,levels=c("Lost","On ledger")), 
            `Fraction [%]`=100*`Fraction`
        )],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Submitted [minute]`, y=`Fraction [%]`, fill=`Outcome`)
) +
    geom_bar(stat="identity") +
    facet_varied() +
    ggtitle("Transactions reaching the ledger", label) +
    theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
ggsave("plots/temporal-efficiency-bar.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Release memory

# %%
rm(lifecycle, outcomes, totals)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells  965132 51.6  2063228   110.2  2063228 110.2
# Vcells 1771897 13.6 14371808   109.7 17964760 137.1

# %% [markdown]
# ### Resource usage

# %%
if (file.exists("results/resources.Rdata")) {
    load(file="results/resources.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    resources <- fread("results/resources.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(resources, file="results/resources.Rdata")
}
resources[, `Tx validation`:=factor(`Tx validation`, levels=sort_factors(resources[, unique(`Tx validation`)]))]
resources %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#  Simulator                        Variant            Network       Bandwidth
#  Rust:3750   linear-with-tx-references:3750   topology-v2:3750   50 Mb/s:3750
#
#
#
#
#
#
#        Stage length          EB rate       Max EB size        Tx size
#  8 slot/stage:3750   2.5 EB/stage:3750   10 MB/EB:3750   1500 B/Tx:3750
#
#
#
#
#
#
#         Throughput    Tx start [s]  Tx stop [s]   Sim stop [s]
#  0.150 TxMB/s:3750   Min.   :60    Min.   :960   Min.   :1200
#                      1st Qu.:60    1st Qu.:960   1st Qu.:1200
#                      Median :60    Median :960   Median :1200
#                      Mean   :60    Mean   :960   Mean   :1200
#                      3rd Qu.:60    3rd Qu.:960   3rd Qu.:1200
#                      Max.   :60    Max.   :960   Max.   :1200
#
#       Tx validation       Node        Egress [B]           Disk [B]
#  1.00 ms/Tx  :750   node-0  :   5   Min.   :      210   Min.   :     0
#  3.00 ms/Tx  :750   node-1  :   5   1st Qu.:  7213802   1st Qu.:     0
#  10.00 ms/Tx :750   node-10 :   5   Median : 99890114   Median :     0
#  30.00 ms/Tx :750   node-100:   5   Mean   :137001323   Mean   : 15304
#  100.00 ms/Tx:750   node-101:   5   3rd Qu.:197114542   3rd Qu.:     0
#                     node-102:   5   Max.   :937142738   Max.   :913728
#                     (Other) :3720
#  Total CPU [s]    Maximum CPU [s/s]
#  Min.   : 229.0   Min.   : 5.297
#  1st Qu.: 418.1   1st Qu.: 5.516
#  Median :1047.1   Median : 6.256
#  Mean   :2277.7   Mean   : 7.371
#  3rd Qu.:2848.2   3rd Qu.: 8.405
#  Max.   :6843.8   Max.   :15.799

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `Nodal egress [Mb/s]`=8*`Egress [B]`/simFinish/1e6)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`Nodal egress [Mb/s]`)
) +
    geom_violin() +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("Network", label)
# Out:
# plot without title

# %%
ggsave("plots/network.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `1-Second peak CPU [vCPU⋅s/s]`=`Maximum CPU [s/s]`)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`1-Second peak CPU [vCPU⋅s/s]`)
) +
    geom_boxplot() +
    ylim(0, NA) +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("1-Second Peak CPU", label)
# Out:
# plot without title

# %%
ggsave("plots/cpu-peak.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `Mean CPU [vCPU⋅s/s]`=`Total CPU [s]`/simFinish)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`Mean CPU [vCPU⋅s/s]`)
) +
    geom_boxplot() +
    ylim(0, NA) +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("Mean CPU", label)
# Out:
# plot without title

# %%
ggsave("plots/cpu-mean.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Release memory

# %%
rm(resources)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells  995252 53.2  2063228   110.2  2063228 110.2
# Vcells 1830225 14.0 11497447    87.8 17964760 137.1

# %% [markdown]
# ### Receipt of messages

# %% [markdown]
# #### Read results

# %%
if (file.exists("results/receipts.Rdata")) {
    load("results/receipts.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    receipts <- fread("results/receipts.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(receipts, file="results/receipts.Rdata")
}
setnames(receipts, old="Kind", new="Message")
receipts[, `Tx validation`:=factor(`Tx validation`, levels=sort_factors(receipts[, unique(`Tx validation`)]))]
receipts %>% summary
# Out:
# Loaded Rdata file: sampleSize = 0.33
#  Simulator                             Variant                 Network
#  Rust:119156850   linear-with-tx-references:119156850   topology-v2:119156850
#
#
#
#
#
#
#    Bandwidth               Stage length               EB rate
#  50 Mb/s:119156850   8 slot/stage:119156850   2.5 EB/stage:119156850
#
#
#
#
#
#
#    Max EB size             Tx size                 Throughput
#  10 MB/EB:119156850   1500 B/Tx:119156850   0.150 TxMB/s:119156850
#
#
#
#
#
#
#   Tx start [s]  Tx stop [s]   Sim stop [s]       Tx validation
#  Min.   :60    Min.   :960   Min.   :1200   1.00 ms/Tx  :24699577
#  1st Qu.:60    1st Qu.:960   1st Qu.:1200   3.00 ms/Tx  :24698334
#  Median :60    Median :960   Median :1200   10.00 ms/Tx :24698813
#  Mean   :60    Mean   :960   Mean   :1200   30.00 ms/Tx :24703264
#  3rd Qu.:60    3rd Qu.:960   3rd Qu.:1200   100.00 ms/Tx:20356862
#  Max.   :60    Max.   :960   Max.   :1200
#
#  Message                  Item               Producer         Generated [s]
#  EB:    63887   26-node-95  :     4091   node-541:   247824   Min.   :  20.07
#  RB:    66443   105-node-598:     3894   node-70 :   245543   1st Qu.: 284.19
#  TX:109181193   299-node-558:     3852   node-474:   244985   Median : 512.61
#  VT:  9845327   54-node-525 :     3851   node-448:   238021   Mean   : 512.22
#                 65-node-61  :     3741   node-331:   236970   3rd Qu.: 735.50
#                 79-node-134 :     3732   node-707:   227670   Max.   :1173.85
#                 (Other)     :119133689   (Other) :117715837
#     Size [B]         Recipient          Received [s]      Elapsed [s]
#  Min.   :   105   node-248:   161405   Min.   :  20.08   Min.   :  0.0003
#  1st Qu.:  1500   node-484:   161328   1st Qu.: 295.58   1st Qu.:  0.1106
#  Median :  1500   node-450:   161263   Median : 537.28   Median :  0.1810
#  Mean   :  1478   node-24 :   161252   Mean   : 537.72   Mean   : 25.5011
#  3rd Qu.:  1500   node-250:   161241   3rd Qu.: 771.20   3rd Qu.:  0.6658
#  Max.   :213552   node-645:   161206   Max.   :1200.00   Max.   :789.1948
#                   (Other) :118189155

# %%
kinds <- receipts[, unique(`Message`) %>% sort]
kinds
# Out:
# [1] EB RB TX VT
# Levels: EB RB TX VT

# %% [markdown]
# #### Arrival histograms

# %% [markdown]
# ##### Compare the distributions of elapsed times

# %%
arrivalDelayHistogram <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[, .(`Varied`, `Network`, `Elapsed [s]`, `Minute created`=factor(floor(`Generated [s]`/60)))],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Elapsed [s]`, fill=`Minute created`)
    ) +
        geom_histogram(binwidth=0.1) +
        facet_varied(scales=scales) +
        xlab("Time from generation to receipt at node [s]") +
        ylab("Number received") +
        ggtitle(title, subtitle=label) +
        theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
for (k in kinds)
    arrivalDelayHistogram(
        receipts[`Message` == k],
        paste("Arrival delay for", k),
        scales="free_y",
        outfiles=paste0("plots/elapsed-", k, ".png")
    ) %>% print
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# #### Bandwidth usage

# %% [markdown]
# ##### Total network bandwidth

# %%
totalBandwidthPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Gb]`=8*sum(`Size [B]`, rm.na=TRUE)/1e9/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Gb]`, fill=`Message`)
    ) +
        geom_area() +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Total network ingress [Gb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
totalBandwidthPlot(
    receipts,
    "Total bandwidth",
    scales="free_y",
    outfiles=paste0("plots/ingress-total-area.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Bandwidth usage per node

# %%
nodeCount <- receipts[, length(unique(`Recipient`))]
nodeCount
# Out:
# [1] 750

# %%
meanNodalIngressPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Mb/node]`=8*sum(`Size [B]`)/1e6/ifelse(`Network`=="topology-v1",10000,750)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Mb/node]`, fill=`Message`)
    ) +
        geom_area() +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Mean network ingress among nodes [Mb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanNodalIngressPlot(
    receipts, 
    "Mean nodal ingress",
    scales="free_y",
    outfiles=paste0("plots/ingress-average-area.png")
)
# Out:
# plot without title

# %%
peakNodalIngressPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Mb]`=8*sum(`Size [B]`, rm.na=TRUE)/1e6/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`, `Recipient`)
            ][,
                .(`Size [Mb]`=max(`Size [Mb]`)),
                by=.(`Varied`, `Network`, `Slot`, `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Mb]`, color=`Message`)
    ) +
        geom_point(size=0.5) +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Maximum network ingress among nodes [Mb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakNodalIngressPlot(
    receipts, 
    "Peak nodal ingress",
    outfiles=paste0("plots/ingress-peak-point.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Release memory

# %%
rm(receipts)

# %%
gc()
# Out:
#        used       (Mb)    gc trigger (Mb)    max used   (Mb)
# Ncells    1105833    59.1    2607248   139.3    2607248   139.3
# Vcells 1492002789 11383.1 4096999919 31257.7 5121216178 39071.8

# %% [markdown]
# ### CPU usage

# %% [markdown]
# #### Read results

# %%
if (file.exists("results/cpus.Rdata")) {
    load(file="results/cpus.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    cpus <- fread("results/cpus.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(cpus, file="results/cpus.Rdata")
}
cpus[, `Tx validation`:=factor(`Tx validation`, levels=sort_factors(cpus[, unique(`Tx validation`)]))]
cpus %>% summary
# Out:
# Loaded Rdata file: sampleSize = 0.33
#  Simulator                             Variant                 Network
#  Rust:115854494   linear-with-tx-references:115854494   topology-v2:115854494
#
#
#
#
#
#
#    Bandwidth               Stage length               EB rate
#  50 Mb/s:115854494   8 slot/stage:115854494   2.5 EB/stage:115854494
#
#
#
#
#
#
#    Max EB size             Tx size                 Throughput
#  10 MB/EB:115854494   1500 B/Tx:115854494   0.150 TxMB/s:115854494
#
#
#
#
#
#
#   Tx start [s]  Tx stop [s]   Sim stop [s]       Tx validation
#  Min.   :60    Min.   :960   Min.   :1200   1.00 ms/Tx  :24730664
#  1st Qu.:60    1st Qu.:960   1st Qu.:1200   3.00 ms/Tx  :24729423
#  Median :60    Median :960   Median :1200   10.00 ms/Tx :24729935
#  Mean   :60    Mean   :960   Mean   :1200   30.00 ms/Tx :24734392
#  3rd Qu.:60    3rd Qu.:960   3rd Qu.:1200   100.00 ms/Tx:16930080
#  Max.   :60    Max.   :960   Max.   :1200
#
#       Slot              Node                Task            Duration [s]
#  Min.   :  20.0   node-187:   155354   ValTX  :105740635   Min.   :0.000164
#  1st Qu.: 294.0   node-539:   155343   ValVote:  9847234   1st Qu.:0.001000
#  Median : 535.0   node-576:   155333   ValRB  :    65656   Median :0.010000
#  Mean   : 535.7   node-230:   155321   ValRH  :    64039   Mean   :0.024329
#  3rd Qu.: 769.0   node-134:   155316   ValEH  :    62203   3rd Qu.:0.030000
#  Max.   :1200.0   node-384:   155279   ValEB  :    61435   Max.   :5.049500
#                   (Other) :114922548   (Other):    13292

# %%
cpusNode <-
    substitute(
        cpus[
            ,
            .(`Duration [s]`=sum(`Duration [s]`)),
            by=.(`Varied`, `Network`, `Node`, `Slot`)
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval

# %%
nodeCount <- cpusNode[, length(unique(`Node`))]
nodeCount
# Out:
# [1] 750

# %% [markdown]
# #### Peak CPU usage

# %% [markdown]
# ##### Histogram

# %%
peakCpuHistogram <- function(cs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*max(`Duration [s]`)),
                by=.(`Varied`, `Network`, `Slot`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Duration [%]`)
    ) +
        geom_histogram(binwidth=10) +
        facet_varied(scales=scales) +
        xlab("Peak CPU load [%]") +
        ylab("Number of slots") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakCpuHistogram(
    cpusNode, 
    "Peak CPU load among all nodes",
    scales="free_y",
    outfiles=paste0("plots/cpu-peak-histogram.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Time series

# %%
peakCpuTimeseries <- function(cs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*mean(`Duration [s]`)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Duration [%]`)) +
        geom_line() +
        facet_varied(scale=scales) +
        xlab("Slot") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakCpuTimeseries(
    cpusNode,
    "Peak CPU load among all nodes",
    outfiles=paste0("plots/cpu-peak-timeseries.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Mean CPU usage

# %% [markdown]
# ##### Histogram

# %%
meanCpuHistogram <- function(cs, nodeSeconds, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*sum(`Duration [s]`)/nodeSeconds/ifelse(`Network` == "topology-v1", 10000, 750)),
                by=.(`Varied`, `Network`, `Task`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x="", fill=`Task`, y=`Duration [%]`)) +
        geom_bar(stat = "identity") +
        facet_varied(wide=TRUE, scales=scales) +
        xlab("") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanCpuHistogram(
    cpus[`Slot` >= txFirst & `Slot` < txLast],
    txWindow * sampleSize, 
    "Mean CPU load among all nodes", 
    scales="free_y",
    outfiles=paste0("plots/cpu-mean-histogram.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Time series

# %%
meanCpuTimeseries <- function(cs, nodeSeconds, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*sum(`Duration [s]`)/nodeSeconds/ifelse(`Network`=="topology-v1",10000,750)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`, `Task`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Duration [%]`, color=`Task`)
    ) +
        geom_point(size=0.25, alpha=0.75) +
        facet_varied(scales=scales) +
        scale_y_sqrt() +
        xlab("Slot") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanCpuTimeseries(
    cpus, 
    sampleSize, 
    "Mean CPU load among all nodes",
    outfiles=paste0("plots/cpu-mean-timeseries.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Release memory

# %%
rm(cpus, cpusNode)

# %%
gc()
# Out:
#        used       (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells    1013010   54.2    2607248   139.3    2607248   139.3
# Vcells 1045046479 7973.1 3277599936 25006.2 5121216178 39071.8

# %% [markdown]
# ## Block contents

# %% [markdown]
# ### Read data

# %%
sizes <- fread("results/sizes.csv.gz", stringsAsFactors=TRUE)
setnames(sizes, old="Kind", new="Message")
sizes[, `Tx validation`:=factor(`Tx validation`, levels=sort_factors(sizes[, unique(`Tx validation`)]))]
sizes %>% summary
# Out:
#  Simulator                       Variant           Network      Bandwidth
#  Rust:596   linear-with-tx-references:596   topology-v2:596   50 Mb/s:596
#
#
#
#
#
#
#        Stage length         EB rate      Max EB size       Tx size
#  8 slot/stage:596   2.5 EB/stage:596   10 MB/EB:596   1500 B/Tx:596
#
#
#
#
#
#
#         Throughput   Tx start [s]  Tx stop [s]   Sim stop [s]
#  0.150 TxMB/s:596   Min.   :60    Min.   :960   Min.   :1200
#                     1st Qu.:60    1st Qu.:960   1st Qu.:1200
#                     Median :60    Median :960   Median :1200
#                     Mean   :60    Mean   :960   Mean   :1200
#                     3rd Qu.:60    3rd Qu.:960   3rd Qu.:1200
#                     Max.   :60    Max.   :960   Max.   :1200
#
#       Tx validation Message            Item     Generated [s]
#  1.00 ms/Tx  :114   EB:298   105-node-598: 10   Min.   :  20.07
#  3.00 ms/Tx  :114   RB:298   131-node-573: 10   1st Qu.: 383.07
#  10.00 ms/Tx :114            177-node-149: 10   Median : 650.08
#  30.00 ms/Tx :114            20-node-220 : 10   Mean   : 631.70
#  100.00 ms/Tx:140            26-node-95  : 10   3rd Qu.: 931.08
#                              296-node-99 : 10   Max.   :1194.36
#                              (Other)     :536
#   Transactions           Endorses
#  Min.   :   0   1082-node-207:  8
#  1st Qu.:  60   26-node-95   :  5
#  Median :  60   1010-node-131:  4
#  Mean   :1867   105-node-598 :  4
#  3rd Qu.:4128   1054-node-476:  4
#  Max.   :6666   (Other)      :100
#                 NA's         :471

# %% [markdown]
# ### EB contents

# %% [markdown]
# #### Transactions

# %%
ggplot(sizes[`Message` == "EB"], aes(x=`Transactions`)) +
    geom_histogram(binwidth=1000) +
    facet_varied() +
    ylab("Number of EBs") +
    ggtitle("Number of transactions in EBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-ebs-txs.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
    substitute(
        sizes[`Message` == "EB", .(`EB size [MB]`=`Transactions`*1400/1e6), .(`Varied`, `Network`)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`EB size [MB]`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
    ylab("Number of EBs") +
    ggtitle("Size of transactions in EBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-ebs-size.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# ### RB contents

# %% [markdown]
# #### Transactions

# %%
ggplot(sizes[`Message` == "RB"], aes(x=`Transactions`)) +
    geom_histogram(binwidth=10) +
    facet_varied() +
    ylab("Number of RBs") +
    ggtitle("Number of transactions in RBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-rbs-txs.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
    substitute(
        sizes[`Message` == "RB", .(`RB size [kB]`=`Transactions`*1400/1e3), .(`Varied`, `Network`)],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`RB size [kB]`)
) +
    geom_histogram(binwidth=10) +
    facet_varied() +
    ylab("Number of RBs") +
    ggtitle("Size of transactions in RBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-rbs-size.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# ## Findings
#
# - Simulation with 6-vCPU nodes supported doubling the Plutus per-transaction budget on Linear Leios.
# - Simulations at a sixfold increase in the Plutus per-transaction budget failed: nodes bogged down validating transactions and cannot put them in new EBs.
# - EB could likely handle 5000 Gstep of Plutus computation in Linear Leios, which is 250x the Praos per-block budget.
#     - This could support a handful of Plutus transactions with a 20x greater Plutus budget.
#     - Alternatively every Plutus transaction could have its budget increased by 50%.
#     - However, intentionally late diffusion of Plutus-heavy transactions could interfere with EB adoption.
# - These results are uncertain due to the variability in measured Plutus CPU costs: there is quite a bit of variability in the CPU time actually used by a Plutus script given its execution steps.

# %% [markdown]
# # Leios simulation analysis at tag `leios-2025w32`

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Load packages

# %%
suppressMessages({
    require(RColorBrewer, quietly=TRUE)
    require(data.table, quietly=TRUE)
    require(ggplot2, quietly=TRUE)
    require(magrittr, quietly=TRUE)
})

# %% [markdown]
# ### Define utility functions

# %%
sort_factors <- function(fs, ascending=TRUE) {
    xs <- fs[as.numeric(sub(" .*$", "", fs)) %>% order]
    if (ascending)
        xs
    else
        rev(xs)
}

# %% [markdown]
# ## Experiment: Linear Leios for CIP

# %% [markdown]
# ### Analysis of lifecycles and efficiencies

# %% [markdown]
# #### Read the lifecycle results

# %%
if (file.exists("results/lifecycle.Rdata")) {
    load(file="results/lifecycle.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    lifecycle <- fread("results/lifecycle.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
    save(lifecycle, sampleSize, file="results/lifecycle.R")
    cat(paste("Saved Rdata file: sampleSize =", sampleSize, "\n"))
}
setnames(lifecycle, old="Kind", new="Message")
lifecycle %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#  Simulator                          Variant              Network
#  Rust:609258   linear-with-tx-references:609258   topology-v2:609258
#
#
#
#
#
#
#    Bandwidth               CPU               Stage length
#  10 Mb/s:609258   4 vCPU/node:609258   7 slot/stage:609258
#
#
#
#
#
#
#          EB rate         Max EB size          Tx size
#  2.5 EB/stage:609258   12 MB/EB:609258   1500 B/Tx:609258
#
#
#
#
#
#
#         Throughput      Tx start [s]  Tx stop [s]   Sim stop [s]  Message
#  0.100 TxMB/s: 60155   Min.   :60    Min.   :960   Min.   :1500   EB:   341
#  0.150 TxMB/s: 90133   1st Qu.:60    1st Qu.:960   1st Qu.:1500   RB:   341
#  0.200 TxMB/s:128704   Median :60    Median :960   Median :1500   TX:608576
#  0.250 TxMB/s:150133   Mean   :60    Mean   :960   Mean   :1500
#  0.300 TxMB/s:180133   3rd Qu.:60    3rd Qu.:960   3rd Qu.:1500
#                        Max.   :60    Max.   :960   Max.   :1500
#
#            Item           Size [B]        References     Created [s]
#  100-node-432:    10   Min.   :   240   Min.   :0.000   Min.   :  20.07
#  105-node-598:    10   1st Qu.:  1500   1st Qu.:1.000   1st Qu.: 285.10
#  131-node-573:    10   Median :  1500   Median :1.000   Median : 510.22
#  177-node-149:    10   Mean   :  1586   Mean   :1.783   Mean   : 510.29
#  20-node-220 :    10   3rd Qu.:  1500   3rd Qu.:2.000   3rd Qu.: 735.28
#  219-node-475:    10   Max.   :256240   Max.   :4.000   Max.   :1495.08
#  (Other)     :609198
#  To IB [s]        To EB [s]         To RB [s]         In RB [s]
#  Mode:logical   Min.   :  65.08   Min.   :  54.08   Min.   :  65.1
#  NA's:609258    1st Qu.: 383.07   1st Qu.: 419.07   1st Qu.: 383.1
#                 Median : 552.08   Median : 591.08   Median : 571.1
#                 Mean   : 556.40   Mean   : 599.27   Mean   : 544.8
#                 3rd Qu.: 767.08   3rd Qu.: 812.08   3rd Qu.: 767.1
#                 Max.   :1040.08   Max.   :1494.08   Max.   :1040.1
#                 NA's   :7462      NA's   :12752     NA's   :597018

# %%
label <- lifecycle[, unique(paste(`Simulator`, `Variant`, `Network`, `CPU`, `Bandwidth`, `Stage length`, `Max EB size`, `Tx size`, sep=", "))]

# %%
fixed <- c("Simulator", "Variant", "Network", "Bandwidth", "CPU", "Stage length", "EB rate", "Max EB size", "Tx size")

# %%
varied <- c("Throughput")

# %%
facet_varied <- function(scales="free_y", wide=FALSE) {
    if (wide)
        facet_grid(. ~ `Throughput`, scales=scales)
    else
        facet_grid(`Throughput` ~ ., scales=scales)
}

# %% [markdown]
# #### Range of transaction injection

# %%
txFirst <- lifecycle[, median(`Tx start [s]`)]
txLast <- lifecycle[, median(`Tx stop [s]`)]
txWindow <- txLast - txFirst
simFinish <- lifecycle[, median(`Sim stop [s]`)]

# %%
ggplot(lifecycle, aes(x=`Created [s]`)) +
    geom_histogram(binwidth=5, fill="lightgray") +
    geom_vline(xintercept=txFirst, color="blue") +
    geom_vline(xintercept=txLast, color="red") +
    ylab("Number of Transactions") +
    ggtitle("Time range of Transactions", label)
# Out:
# plot without title

# %% [markdown]
# #### Actual TPS

# %%
dtmp <- lifecycle[
    `Message` == "TX" & `Created [s]` >= txFirst & `Created [s]` <= txLast, 
    .(
        `Demand [tx/s]`=.N/txWindow
    ),
    c(fixed, varied)
]
setorderv(dtmp, varied)
dtmp
# Out:
#   Simulator Variant                   Network     Bandwidth CPU
# 1 Rust      linear-with-tx-references topology-v2 10 Mb/s   4 vCPU/node
# 2 Rust      linear-with-tx-references topology-v2 10 Mb/s   4 vCPU/node
# 3 Rust      linear-with-tx-references topology-v2 10 Mb/s   4 vCPU/node
# 4 Rust      linear-with-tx-references topology-v2 10 Mb/s   4 vCPU/node
# 5 Rust      linear-with-tx-references topology-v2 10 Mb/s   4 vCPU/node
#   Stage length EB rate      Max EB size Tx size   Throughput   Demand [tx/s]
# 1 7 slot/stage 2.5 EB/stage 12 MB/EB    1500 B/Tx 0.100 TxMB/s  66.66778
# 2 7 slot/stage 2.5 EB/stage 12 MB/EB    1500 B/Tx 0.150 TxMB/s 100.00111
# 3 7 slot/stage 2.5 EB/stage 12 MB/EB    1500 B/Tx 0.200 TxMB/s 142.85778
# 4 7 slot/stage 2.5 EB/stage 12 MB/EB    1500 B/Tx 0.250 TxMB/s 166.66778
# 5 7 slot/stage 2.5 EB/stage 12 MB/EB    1500 B/Tx 0.300 TxMB/s 200.00000

# %% [markdown]
# #### Size of persisted data

# %%
ggplot(
    lifecycle[,
        .(`Size [kB/s]`=sum(`Size [B]`)/1e3/600),
        c(varied, "Message")
    ],
    aes(x=!!sym(varied), y=`Size [kB/s]`, fill=`Message`)
) + geom_bar(stat="identity") +
    ggtitle("Size of diffused data", subtitle=label)
# Out:
# plot without title

# %%
ggsave("plots/sizes.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Spatial efficiency

# %%
dtmp <- lifecycle[
        `Message` == "TX", 
        .(`Tx size [B]`=sum(ifelse(is.na(`To RB [s]`) & is.na(`In RB [s]`), 0, 1.0 * `Size [B]`))),
        varied
    ][
        lifecycle[
            , 
            .(`Non-tx size [B]`=sum(as.numeric((`Variant` != "linear" & `Message` == "TX" | `Message` == "EB" | `Message` == "RB") * `Size [B]`))), 
            varied
        ],
        on=varied
    ][, .(`Space efficiency [%]`=100*`Tx size [B]`/`Non-tx size [B]`), varied]
setorderv(dtmp, varied)
dtmp
# Out:
#   Throughput   Space efficiency [%]
# 1 0.100 TxMB/s 92.22120
# 2 0.150 TxMB/s 94.08732
# 3 0.200 TxMB/s 94.69080
# 4 0.250 TxMB/s 94.92100
# 5 0.300 TxMB/s 94.99451

# %%
ggplot(
    lifecycle[
        `Message` == "TX", 
        .(`Tx size [B]`=sum(ifelse(is.na(`To RB [s]`) & is.na(`In RB [s]`), 0, 1.0 * `Size [B]`))),
        varied
    ][
        lifecycle[
            `Message` != "VT", 
            .(`Non-tx size [B]`=sum(as.numeric((`Variant` != "linear" & `Message` == "TX" | `Message` == "EB" | `Message` == "RB") * `Size [B]`))), 
            varied
        ],
        on=varied
    ][, .(`Space efficiency [%]`=100*`Tx size [B]`/`Non-tx size [B]`), varied],
    aes(x=!!sym(varied), y=`Space efficiency [%]`)
) +
    geom_bar(stat="identity") +
    ylim(0, 100) +
    ggtitle("Spatial efficiency (size of txs on ledger / size of non-tx persisted data)", label)
# Out:
# plot without title

# %%
ggsave("plots/spatial-efficiency.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Time to reach the EB

# %%
dtmp <- lifecycle[
        `Message` == "TX" & 
        !is.na(`To EB [s]`) &
        `Created [s]` >= txFirst & `Created [s]` <= txLast, 
        .(`Time to reach EB [s]`=mean(`To EB [s]`-`Created [s]`)), 
        varied
    ]
setorderv(dtmp, varied)
dtmp
# Out:
#   Throughput   Time to reach EB [s]
# 1 0.100 TxMB/s 19.28722
# 2 0.150 TxMB/s 20.81224
# 3 0.200 TxMB/s 28.92780
# 4 0.250 TxMB/s 42.05979
# 5 0.300 TxMB/s 83.52171

# %%
ggplot(
    substitute(
        lifecycle[
            `Message` == "TX" & 
            !is.na(`To EB [s]`) &
            `Created [s]` >= txFirst & `Created [s]` < txLast, 
            .(`Time to reach EB [s]`=(`To EB [s]`-`Created [s]`)), 
            .(`Varied`, `Minute created`=factor(floor(`Created [s]`/60)))
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Time to reach EB [s]`, fill=`Minute created`)
) + geom_histogram(bins=50, position="stack") +
    facet_varied() +
    xlab("Time for transaction to reach EB [s]") +
    ylab("Number of items") +
    ggtitle("Time for transaction to reach an EB", label) +
    theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
# Out:
# plot without title

# %%
ggsave("plots/reach-eb-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Time to reach the ledger

# %%
dtmp <- lifecycle[
        `Message` == "TX" & 
        !is.na(`To RB [s]`) &
        `Created [s]` >= txFirst & `Created [s]` <= txLast, 
        .(`Time to reach ledger [s]`=mean(`To RB [s]`-`Created [s]`)), 
        varied
    ]
setorderv(dtmp, varied)
dtmp
# Out:
#   Throughput   Time to reach ledger [s]
# 1 0.100 TxMB/s  60.79247
# 2 0.150 TxMB/s  63.78032
# 3 0.200 TxMB/s  71.66897
# 4 0.250 TxMB/s  84.23859
# 5 0.300 TxMB/s 125.83688

# %%
ggplot(
    substitute(
        lifecycle[
            `Message` == "TX" & 
            !is.na(`To RB [s]`) &
            `Created [s]` >= txFirst & `Created [s]` < txLast, 
            .(`Time to reach ledger [s]`=`To RB [s]`-`Created [s]`), 
            .(`Varied`, `Minute created`=factor(floor(`Created [s]`/60)))
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Time to reach ledger [s]`, fill=`Minute created`)
) + geom_histogram(bins=50) +
    facet_varied() +
    xlab("Time for transaction to reach ledger [s]") +
    ylab("Number of items") +
    ggtitle("Time for transaction to reach the ledger", label) +
    theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
# Out:
# plot without title

# %%
ggsave("plots/reach-rb-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Number of references
#
# A *reference* is one of the following:
#
# - A transaction is included in an IB.
# - An IB is referenced by an EB.
# - An EB is referenced by another EB.
#
# In an efficient Leios, the number of references for each data item would be one.
#
# - *Zero references* indicates that the item was not used.
# - *Two or more references* indicates that duplication has occurred.

# %%
ggplot(
    lifecycle[
        `Message` == "EB",
        .(`References`),
        varied
    ], 
    aes(x=`References`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
#   scale_x_sqrt() +
    ylab("Number of EB") +
    ggtitle("Number of EB references (0 = not used, 2+ = duplicated)", label)
# Out:
# plot without title

# %%
ggsave("plots/references-tx.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    lifecycle[
        `Message` == "TX",
        .(`References`),
        varied
    ], 
    aes(x=`References`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
    ylab("Number of TX") +
    ggtitle("Number of TX references (0 = not used, 2+ = duplicated)", label)
# Out:
# plot without title

# %%
ggsave("plots/references-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Temporal efficiency

# %%
toElapsed <- function(created, toRb, inRb) {
    if (!is.na(toRb))
        toRb - created
    else if (!is.na(inRb))
        inRb - created
    else
        as.numeric(NA)
}

# %%
outcomes <- lifecycle[
    `Message` == "TX" & `Created [s]` < txLast,
    .(
        `Submitted [minute]`=factor(floor(`Created [s]`/60)), 
        `Time to reach ledger [s]`=mapply(toElapsed, `Created [s]`, `To RB [s]`, `In RB [s]`)
    ),
    varied
]

# %%
totals <- substitute(
    outcomes[
        , 
        .(
            `Total`=.N, 
            `Lost`=sum(is.na(`Time to reach ledger [s]`)),
            `1st min`=sum(`Time to reach ledger [s]`<=60,na.rm=TRUE),
            `2nd min`=sum(`Time to reach ledger [s]`>60&`Time to reach ledger [s]`<=120,na.rm=TRUE),
            `3rd min`=sum(`Time to reach ledger [s]`>120&`Time to reach ledger [s]`<=180,na.rm=TRUE)
        ), 
        .(`Varied`, `Submitted [minute]`)
    ],
    env=list(`Varied`=sym(varied))
) %>% eval

# %% [markdown]
# #### Transactions reaching the ledger

# %%
ggplot(
    substitute(
        melt(
            totals[
                , 
                .(
                    `Ledger in 1st min`=`1st min`/`Total`, 
                    `Ledger in 2nd min`=`2nd min`/`Total`, 
                    `Ledger in 3rd min`=`3rd min`/`Total`, 
                    `Ledger later`=(`Total`-`Lost`-`1st min`-`2nd min`-`3rd min`)/`Total`,
                    `Lost`=`Lost`/`Total`
                ), 
                .(`Varied`, `Submitted [minute]`)
            ],
            id.vars=c(varied, "Submitted [minute]"),
            variable.name="Outcome",
            value.name="Fraction"
        )[, .(
            `Varied`,
            `Submitted [minute]`, 
            `Outcome`=factor(`Outcome`,levels=c("Ledger in 1st min", "Ledger in 2nd min", "Ledger in 3rd min", "Ledger later","Lost")), 
            `Fraction [%]`=100*`Fraction`
        )],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Submitted [minute]`, y=`Fraction [%]`, fill=`Outcome`)
) +
    geom_bar(stat="identity") +
    facet_varied() +
    scale_fill_manual(values=c(
        "Ledger in 1st min"=brewer.pal(n=5, name="Set1")[[2]], 
        "Ledger in 2nd min"=brewer.pal(n=5, name="Set1")[[3]], 
        "Ledger in 3rd min"=brewer.pal(n=5, name="Set1")[[4]], 
        "Ledger later"=brewer.pal(n=5, name="Set1")[[5]],
        "Lost"=brewer.pal(n=5, name="Set1")[[1]]
    )) +
    ggtitle("Transactions reaching the ledger", label) +
    theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
lifecycle[
    `Message` == "TX" & is.na(`To RB [s]`) & is.na(`In RB [s]`),
    .(`Throughput`, `Item`, `Created [s]`, `To EB [s]`)
] %>% head
# Out:
#      Throughput Item Created [s] To EB [s]

# %%
ggsave("plots/temporal-efficiency-bar.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Release memory

# %%
rm(lifecycle, outcomes, totals)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells  984454 52.6  2324415   124.2  2324415 124.2
# Vcells 1879124 14.4 21399267   163.3 26749083 204.1

# %% [markdown]
# ### Resource usage

# %%
if (file.exists("results/resources.Rdata")) {
    load(file="results/resources.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    resources <- fread("results/resources.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
    save(resources, file="results/resources.Rdata")
    cat(paste("Saved Rdata file: sampleSize =", sampleSize, "\n"))
}
resources %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#  Simulator                        Variant            Network       Bandwidth
#  Rust:3750   linear-with-tx-references:3750   topology-v2:3750   10 Mb/s:3750
#
#
#
#
#
#
#           CPU             Stage length          EB rate       Max EB size
#  4 vCPU/node:3750   7 slot/stage:3750   2.5 EB/stage:3750   12 MB/EB:3750
#
#
#
#
#
#
#       Tx size            Throughput   Tx start [s]  Tx stop [s]   Sim stop [s]
#  1500 B/Tx:3750   0.100 TxMB/s:750   Min.   :60    Min.   :960   Min.   :1500
#                   0.150 TxMB/s:750   1st Qu.:60    1st Qu.:960   1st Qu.:1500
#                   0.200 TxMB/s:750   Median :60    Median :960   Median :1500
#                   0.250 TxMB/s:750   Mean   :60    Mean   :960   Mean   :1500
#                   0.300 TxMB/s:750   3rd Qu.:60    3rd Qu.:960   3rd Qu.:1500
#                                      Max.   :60    Max.   :960   Max.   :1500
#
#        Node        Egress [B]           Disk [B]       Total CPU [s]
#  node-0  :   5   Min.   :9.450e+03   Min.   :      0   Min.   : 58.68
#  node-1  :   5   1st Qu.:1.238e+07   1st Qu.:      0   1st Qu.: 78.16
#  node-10 :   5   Median :1.139e+08   Median :      0   Median :107.11
#  node-100:   5   Mean   :1.876e+08   Mean   :  14175   Mean   :102.73
#  node-101:   5   3rd Qu.:2.474e+08   3rd Qu.:      0   3rd Qu.:122.90
#  node-102:   5   Max.   :1.742e+09   Max.   :1041792   Max.   :145.92
#  (Other) :3720
#  Maximum CPU [s/s]
#  Min.   :0.9995
#  1st Qu.:1.4636
#  Median :1.4938
#  Mean   :1.4327
#  3rd Qu.:1.5116
#  Max.   :2.9489

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `Nodal egress [Mb/s]`=8*`Egress [B]`/simFinish/1e6)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`Nodal egress [Mb/s]`)
) +
    geom_violin() +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("Network", label)
# Out:
# plot without title

# %%
ggsave("plots/network.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `1-Second peak CPU [vCPU⋅s/s]`=`Maximum CPU [s/s]`)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`1-Second peak CPU [vCPU⋅s/s]`)
) +
    geom_boxplot() +
    ylim(0, NA) +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("1-Second Peak CPU", label)
# Out:
# plot without title

# %%
ggsave("plots/cpu-peak.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `Mean CPU [vCPU⋅s/s]`=`Total CPU [s]`/simFinish)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`Mean CPU [vCPU⋅s/s]`)
) +
    geom_boxplot() +
    ylim(0, NA) +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("Mean CPU", label)
# Out:
# plot without title

# %%
ggsave("plots/cpu-mean.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Release memory

# %%
rm(resources)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells 1014136 54.2  2324415   124.2  2324415 124.2
# Vcells 1923731 14.7 13695532   104.5 26749083 204.1

# %% [markdown]
# ### Receipt of messages

# %% [markdown]
# #### Read results

# %%
if (file.exists("results/receipts.Rdata")) {
    load("results/receipts.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    receipts <- fread("results/receipts.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
    save(receipts, file="results/receipts.Rdata")
    cat(paste("Saved Rdata file: sampleSize =", sampleSize, "\n"))
}
setnames(receipts, old="Kind", new="Message")
receipts %>% summary
# Out:
# Loaded Rdata file: sampleSize = 0.5
#  Simulator                             Variant                 Network
#  Rust:251268499   linear-with-tx-references:251268499   topology-v2:251268499
#
#
#
#
#
#
#    Bandwidth                  CPU                  Stage length
#  10 Mb/s:251268499   4 vCPU/node:251268499   7 slot/stage:251268499
#
#
#
#
#
#
#          EB rate            Max EB size             Tx size
#  2.5 EB/stage:251268499   12 MB/EB:251268499   1500 B/Tx:251268499
#
#
#
#
#
#
#         Throughput        Tx start [s]  Tx stop [s]   Sim stop [s]
#  0.100 TxMB/s:27668670   Min.   :60    Min.   :960   Min.   :1500
#  0.150 TxMB/s:38244314   1st Qu.:60    1st Qu.:960   1st Qu.:1500
#  0.200 TxMB/s:52688931   Median :60    Median :960   Median :1500
#  0.250 TxMB/s:60715606   Mean   :60    Mean   :960   Mean   :1500
#  0.300 TxMB/s:71950978   3rd Qu.:60    3rd Qu.:960   3rd Qu.:1500
#                          Max.   :60    Max.   :960   Max.   :1500
#
#  Message                  Item               Producer         Generated [s]
#  EB:   128159   26-node-95  :     6890   node-671:   540661   Min.   :  20.07
#  RB:   155701   54-node-525 :     6340   node-464:   534869   1st Qu.: 293.57
#  TX:227936184   591-node-487:     5830   node-405:   511045   Median : 528.61
#  VT: 23048455   839-node-148:     5803   node-258:   502125   Mean   : 533.31
#                 65-node-61  :     5800   node-329:   487575   3rd Qu.: 757.86
#                 618-node-475:     5791   node-465:   467803   Max.   :1498.00
#                 (Other)     :251232045   (Other) :248224421
#     Size [B]         Recipient          Received [s]      Elapsed [s]
#  Min.   :   105   node-524:   336451   Min.   :  20.08   Min.   :0.0004
#  1st Qu.:  1500   node-189:   336262   1st Qu.: 293.83   1st Qu.:0.0912
#  Median :  1500   node-155:   336237   Median : 528.86   Median :0.1304
#  Mean   :  1451   node-157:   336172   Mean   : 533.56   Mean   :0.2537
#  3rd Qu.:  1500   node-97 :   336139   3rd Qu.: 758.12   3rd Qu.:0.3023
#  Max.   :256240   node-49 :   336122   Max.   :1499.98   Max.   :2.9989
#                   (Other) :249251116

# %%
kinds <- receipts[, unique(`Message`) %>% sort]
kinds
# Out:
# [1] EB RB TX VT
# Levels: EB RB TX VT

# %% [markdown]
# #### Arrival histograms

# %% [markdown]
# ##### Compare the distributions of elapsed times

# %%
arrivalDelayHistogram <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[, .(`Varied`, `Network`, `Elapsed [s]`, `Minute created`=factor(floor(`Generated [s]`/60)))],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Elapsed [s]`, fill=`Minute created`)
    ) +
        geom_histogram(binwidth=0.1) +
        facet_varied(scales=scales) +
        xlab("Time from generation to receipt at node [s]") +
        ylab("Number received") +
        ggtitle(title, subtitle=label) +
        theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
for (k in kinds)
    arrivalDelayHistogram(
        receipts[`Message` == k],
        paste("Arrival delay for", k),
        scales="free_y",
        outfiles=paste0("plots/elapsed-", k, ".png")
    ) %>% print
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# #### Bandwidth usage

# %% [markdown]
# ##### Total network bandwidth

# %%
totalBandwidthPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Gb]`=8*sum(`Size [B]`, rm.na=TRUE)/1e9/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Gb]`, fill=`Message`)
    ) +
        geom_area() +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Total network ingress [Gb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
totalBandwidthPlot(
    receipts,
    "Total bandwidth",
    scales="free_y",
    outfiles=paste0("plots/ingress-total-area.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Bandwidth usage per node

# %%
nodeCount <- receipts[, length(unique(`Recipient`))]
nodeCount
# Out:
# [1] 750

# %%
meanNodalIngressPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Mb/node]`=8*sum(`Size [B]`)/1e6/ifelse(`Network`=="topology-v1",10000,750)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Mb/node]`, fill=`Message`)
    ) +
        geom_area() +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Mean network ingress among nodes [Mb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanNodalIngressPlot(
    receipts, 
    "Mean nodal ingress",
    scales="free_y",
    outfiles=paste0("plots/ingress-average-area.png")
)
# Out:
# plot without title

# %%
peakNodalIngressPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Mb]`=8*sum(`Size [B]`, rm.na=TRUE)/1e6/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`, `Recipient`)
            ][,
                .(`Size [Mb]`=max(`Size [Mb]`)),
                by=.(`Varied`, `Network`, `Slot`, `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Mb]`, color=`Message`)
    ) +
        geom_point(size=0.5) +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Maximum network ingress among nodes [Mb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakNodalIngressPlot(
    receipts, 
    "Peak nodal ingress",
    outfiles=paste0("plots/ingress-peak-point.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Release memory

# %%
rm(receipts)

# %%
gc()
# Out:
#        used       (Mb)    gc trigger (Mb)    max used    (Mb)
# Ncells    1224961    65.5    2855880   152.6     2855880   152.6
# Vcells 3143241284 23981.1 8565047544 65346.2 10706309429 81682.7

# %% [markdown]
# ### CPU usage

# %% [markdown]
# #### Read results

# %%
if (file.exists("results/cpus.Rdata")) {
    load(file="results/cpus.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    cpus <- fread("results/cpus.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
    save(cpus, file="results/cpus.Rdata")
    cat(paste("Saved Rdata file: sampleSize =", sampleSize, "\n"))
}
cpus %>% summary
# Out:
# Loaded Rdata file: sampleSize = 0.5
#  Simulator                             Variant                 Network
#  Rust:251554859   linear-with-tx-references:251554859   topology-v2:251554859
#
#
#
#
#
#
#    Bandwidth                  CPU                  Stage length
#  10 Mb/s:251554859   4 vCPU/node:251554859   7 slot/stage:251554859
#
#
#
#
#
#
#          EB rate            Max EB size             Tx size
#  2.5 EB/stage:251554859   12 MB/EB:251554859   1500 B/Tx:251554859
#
#
#
#
#
#
#         Throughput        Tx start [s]  Tx stop [s]   Sim stop [s]
#  0.100 TxMB/s:27733072   Min.   :60    Min.   :960   Min.   :1500
#  0.150 TxMB/s:38299993   1st Qu.:60    1st Qu.:960   1st Qu.:1500
#  0.200 TxMB/s:52744585   Median :60    Median :960   Median :1500
#  0.250 TxMB/s:60770973   Mean   :60    Mean   :960   Mean   :1500
#  0.300 TxMB/s:72006236   3rd Qu.:60    3rd Qu.:960   3rd Qu.:1500
#                          Max.   :60    Max.   :960   Max.   :1500
#
#       Slot              Node                Task            Duration [s]
#  Min.   :  20.0   node-93 :   336732   ValTX  :227935375   Min.   :0.0001481
#  1st Qu.: 293.0   node-443:   336714   ValVote: 23049892   1st Qu.:0.0004284
#  Median : 529.0   node-181:   336686   ValRB  :   156225   Median :0.0004284
#  Mean   : 533.4   node-604:   336685   ValRH  :   128090   Mean   :0.0007657
#  3rd Qu.: 758.0   node-94 :   336619   ValEB  :   127294   3rd Qu.:0.0004284
#  Max.   :1499.0   node-212:   336600   ValEH  :   127009   Max.   :1.3681481
#                   (Other) :249534823   (Other):    30974

# %%
cpusNode <-
    substitute(
        cpus[
            ,
            .(`Duration [s]`=sum(`Duration [s]`)),
            by=.(`Varied`, `Network`, `Node`, `Slot`)
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval

# %%
nodeCount <- cpusNode[, length(unique(`Node`))]
nodeCount
# Out:
# [1] 750

# %% [markdown]
# #### Peak CPU usage

# %% [markdown]
# ##### Histogram

# %%
peakCpuHistogram <- function(cs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*max(`Duration [s]`)),
                by=.(`Varied`, `Network`, `Slot`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Duration [%]`)
    ) +
        geom_histogram(binwidth=10) +
        facet_varied(scales=scales) +
        xlab("Peak CPU load [%]") +
        ylab("Number of slots") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakCpuHistogram(
    cpusNode, 
    "Peak CPU load among all nodes",
    scales="free_y",
    outfiles=paste0("plots/cpu-peak-histogram.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Time series

# %%
peakCpuTimeseries <- function(cs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*mean(`Duration [s]`)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Duration [%]`)) +
        geom_line() +
        facet_varied(scale=scales) +
        xlab("Slot") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakCpuTimeseries(
    cpusNode,
    "Mean CPU load among all nodes",
    outfiles=paste0("plots/cpu-peak-timeseries.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Mean CPU usage

# %% [markdown]
# ##### Histogram

# %%
meanCpuHistogram <- function(cs, nodeSeconds, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*sum(`Duration [s]`)/nodeSeconds/ifelse(`Network` == "topology-v1", 10000, 750)),
                by=.(`Varied`, `Network`, `Task`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x="", fill=`Task`, y=`Duration [%]`)) +
        geom_bar(stat = "identity") +
        facet_varied(wide=TRUE, scales=scales) +
        xlab("") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanCpuHistogram(
    cpus[`Slot` >= txFirst & `Slot` < txLast],
    txWindow * sampleSize, 
    "Mean CPU load among all nodes", 
    scales="free_y",
    outfiles=paste0("plots/cpu-mean-histogram.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Time series

# %%
meanCpuTimeseries <- function(cs, nodeSeconds, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*sum(`Duration [s]`)/nodeSeconds/ifelse(`Network`=="topology-v1",10000,750)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`, `Task`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Duration [%]`, color=`Task`)
    ) +
        geom_point(size=0.25, alpha=0.75) +
        facet_varied(scales=scales) +
        scale_y_sqrt() +
        xlab("Slot") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanCpuTimeseries(
    cpus, 
    sampleSize, 
    "Mean CPU load among all nodes",
    outfiles=paste0("plots/cpu-mean-timeseries.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Release memory

# %%
rm(cpus, cpusNode)

# %%
gc()
# Out:
#        used       (Mb)    gc trigger (Mb)    max used    (Mb)
# Ncells    1033457    55.2    2855880   152.6     2855880   152.6
# Vcells 2265980830 17288.1 6852038036 52277.0 10706309429 81682.7

# %% [markdown]
# ## Block contents

# %% [markdown]
# ### Read data

# %%
if (file.exists("results/sizes.Rdata")) {
    load(file="results/sizes.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    sizes <- fread("results/sizes.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
    save(sizes, file="results/sizes.Rdata")
    cat(paste("Saved Rdata file: sampleSize =", sampleSize, "\n"))
}
setnames(sizes, old="Kind", new="Message")
sizes %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#  Simulator                       Variant           Network      Bandwidth
#  Rust:682   linear-with-tx-references:682   topology-v2:682   10 Mb/s:682
#
#
#
#
#
#
#           CPU            Stage length         EB rate      Max EB size
#  4 vCPU/node:682   7 slot/stage:682   2.5 EB/stage:682   12 MB/EB:682
#
#
#
#
#
#
#       Tx size           Throughput   Tx start [s]  Tx stop [s]   Sim stop [s]
#  1500 B/Tx:682   0.100 TxMB/s:154   Min.   :60    Min.   :960   Min.   :1500
#                  0.150 TxMB/s:132   1st Qu.:60    1st Qu.:960   1st Qu.:1500
#                  0.200 TxMB/s:132   Median :60    Median :960   Median :1500
#                  0.250 TxMB/s:132   Mean   :60    Mean   :960   Mean   :1500
#                  0.300 TxMB/s:132   3rd Qu.:60    3rd Qu.:960   3rd Qu.:1500
#                                     Max.   :60    Max.   :960   Max.   :1500
#
#  Message            Item     Generated [s]      Transactions
#  EB:341   100-node-432: 10   Min.   :  20.07   Min.   :   0
#  RB:341   105-node-598: 10   1st Qu.: 432.07   1st Qu.:   0
#           131-node-573: 10   Median : 768.08   Median :  60
#           177-node-149: 10   Mean   : 768.27   Mean   :1593
#           20-node-220 : 10   3rd Qu.:1118.08   3rd Qu.:2060
#           219-node-475: 10   Max.   :1495.08   Max.   :8000
#           (Other)     :622
#          Endorses
#  105-node-598:  5
#  131-node-573:  5
#  177-node-149:  5
#  219-node-475:  5
#  26-node-95  :  5
#  (Other)     :146
#  NA's        :511

# %% [markdown]
# ### EB contents

# %% [markdown]
# #### Transactions

# %%
ggplot(sizes[`Message` == "EB"], aes(x=`Transactions`)) +
    geom_histogram(binwidth=1000) +
    facet_varied() +
    ylab("Number of EBs") +
    ggtitle("Number of transactions in EBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-ebs-txs.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
    substitute(
        sizes[`Message` == "EB", .(`EB size [MB]`=`Transactions`*1400/1e6), .(`Varied`, `Network`)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`EB size [MB]`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
    ylab("Number of EBs") +
    ggtitle("Size of transactions in EBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-ebs-size.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# ### RB contents

# %% [markdown]
# #### Transactions

# %%
ggplot(sizes[`Message` == "RB"], aes(x=`Transactions`)) +
    geom_histogram(binwidth=10) +
    facet_varied() +
    ylab("Number of RBs") +
    ggtitle("Number of transactions in RBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-rbs-txs.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
    substitute(
        sizes[`Message` == "RB", .(`RB size [kB]`=`Transactions`*1400/1e3), .(`Varied`, `Network`)],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`RB size [kB]`)
) +
    geom_histogram(binwidth=10) +
    facet_varied() +
    ylab("Number of RBs") +
    ggtitle("Size of transactions in RBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-rbs-size.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# ### Disposition of blocks

# %% [markdown]
# #### Data processing

# %%
ebSizes <- 
    substitute(
        sizes[`Message` == "RB" & !is.na(`Endorses`), .(`Certified`=TRUE), .(`Varied`, `Item`=`Endorses`)][
        sizes[`Message` == "EB", .(`EB Transactions`=`Transactions`), .(`Varied`, `Item`)], 
            on=c(varied, "Item")
        ][
            ,
            .(
                `EB txs later not certified`=ifelse(is.na(`Certified`), as.numeric(`EB Transactions`), 0),
                `EB txs later certified`=ifelse(is.na(`Certified`), 0, as.numeric(`EB Transactions`))
            ),
            .(`Varied`, `Item`)
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval

# %%
rbSizes <- 
    substitute(
        ebSizes[
            ebSizes[, .(`EB txs certified now`=`EB txs later certified`), .(`Varied`, `Endorses`=`Item`)][
                sizes[`Message` == "RB", .(`Generated [s]`, `RB Transactions`=as.numeric(`Transactions`)), .(`Varied`, `Item`, `Endorses`)],
                on=c(varied, "Endorses")
            ],
            on=c(varied, "Item")
        ][
            ,
            .(
                `Generated [s]`,
                `RB`=`RB Transactions`,
                `EB later not certified`=`EB txs later not certified`,
                `EB later certified`=`EB txs later certified`,
                `EB now certified`=ifelse(is.na(`EB txs certified now`), 0, `EB txs certified now`)
            ),
            , .(`Varied`, `Item`)
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval

# %%
blocks <- melt(
    rbSizes, 
    id.vars=c(varied, "Item", "Generated [s]"),
    measure.vars=c("RB", "EB later not certified", "EB later certified", "EB now certified"),
    variable.name="Block",
    value.name="Transactions"
)

# %% [markdown]
# #### Sanity checks

# %%
ebSizes[, .N] == sizes[`Message` == "EB", .N]
# Out:
# [1] TRUE

# %%
ebSizes[, sum(`EB txs later not certified`) + sum(`EB txs later certified`)] == sizes[`Message` == "EB", sum(`Transactions`)]
# Out:
# [1] TRUE

# %%
rbSizes[, .N] == sizes[`Message` == "RB", .N]
# Out:
# [1] TRUE

# %%
rbSizes[, sum(`RB`)] == sizes[`Message` == "RB", sum(`Transactions`)]
# Out:
# [1] TRUE

# %%
rbSizes[, sum(`EB later not certified`) + sum(`EB later certified`)] == sizes[`Message` == "EB", sum(`Transactions`)]
# Out:
# [1] TRUE

# %%
# TODO: Compute precise equality that accounts for forks.
rbSizes[, sum(`EB later certified`)] <= rbSizes[, sum(`EB now certified`)]
# Out:
# [1] TRUE

# %% [markdown]
# #### Transactions

# %%
ggplot(
    substitute(
        blocks[, .(`Transactions`=sum(`Transactions`)), .(`Varied`, `Block`, `Minute generated`=(floor(`Generated [s]`/60)))],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Minute generated`, y=`Transactions`, fill=`Block`)
) +
    geom_bar(stat="identity") +
    facet_varied()
# Out:
# plot without title

# %%
ggsave("plots/disposition-txs-timeseries.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        blocks[, .(`Transactions`=sum(`Transactions`)), .(`Varied`, `Block`)],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=!!sym(varied), y=`Transactions`, fill=`Block`)
) +
    geom_bar(stat="identity")
# Out:
# plot without title

# %%
ggsave("plots/disposition-txs-histogram.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
    substitute(
        blocks[, .(`Total size of transactions [MB]`=sum(`Transactions`)*300/1e6), .(`Varied`, `Block`, `Minute of block generation`=(floor(`Generated [s]`/60)))], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Minute of block generation`, y=`Total size of transactions [MB]`, fill=`Block`)
) +
    geom_bar(stat="identity") +
    facet_varied() +
    ggtitle("Disposition of transactions in blocks", label)
# Out:
# plot without title

# %%
ggsave("plots/disposition-size-timeseries.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        blocks[, .(`Total size of transactions [MB]`=sum(`Transactions`)*300/1e6), .(`Varied`, `Block`)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=!!sym(varied), y=`Total size of transactions [MB]`, fill=`Block`)
) +
    geom_bar(stat="identity") +
    ggtitle("Disposition of transactions", label)
# Out:
# plot without title

# %%
ggsave("plots/disposition-size-histogram.png", units="in", dpi=150, width=16, height=8)

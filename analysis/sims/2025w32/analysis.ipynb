# %% [markdown]
# # Leios simulation analysis at tag `leios-2025w32`

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Load packages

# %%
suppressMessages({
    require(data.table, quietly=TRUE)
    require(ggplot2, quietly=TRUE)
    require(magrittr, quietly=TRUE)
})

# %% [markdown]
# ### Define utility functions

# %%
sort_factors <- function(fs, ascending=TRUE) {
    xs <- fs[as.numeric(sub(" .*$", "", fs)) %>% order]
    if (ascending)
        xs
    else
        rev(xs)
}

# %% [markdown]
# ## Experiment: Linear Leios for CIP

# %% [markdown]
# ### Analysis of lifecycles and efficiencies

# %% [markdown]
# #### Read the lifecycle results

# %%
if (file.exists("results/lifecycle.Rdata")) {
    load(file="results/lifecycle.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    lifecycle <- fread("results/lifecycle.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(lifecycle, sampleSize, file="results/lifecycle.R")
}
setnames(lifecycle, old="Kind", new="Message")
lifecycle[, `Stage length`:=factor(`Stage length`, levels=sort_factors(lifecycle[, unique(`Stage length`)]))]
lifecycle %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#  Simulator                          Variant              Network
#  Rust:609096   linear-with-tx-references:609096   topology-v2:609096
#
#
#
#
#
#
#    Bandwidth             Stage length            EB rate
#  50 Mb/s:609096   10 slot/stage:609096   2.5 EB/stage:609096
#
#
#
#
#
#
#    Max EB size          Tx size              Throughput      Tx start [s]
#  25 MB/EB:609096   1500 B/Tx:609096   0.100 TxMB/s: 60105   Min.   :60
#                                       0.150 TxMB/s: 90105   1st Qu.:60
#                                       0.200 TxMB/s:128676   Median :60
#                                       0.250 TxMB/s:150105   Mean   :60
#                                       0.300 TxMB/s:180105   3rd Qu.:60
#                                                             Max.   :60
#
#   Tx stop [s]   Sim stop [s]  Message                Item
#  Min.   :960   Min.   :1200   EB:   260   100-node-432 :    10
#  1st Qu.:960   1st Qu.:1200   RB:   260   1040-node-597:    10
#  Median :960   Median :1200   TX:608576   105-node-598 :    10
#  Mean   :960   Mean   :1200               1078-node-186:    10
#  3rd Qu.:960   3rd Qu.:1200               1088-node-151:    10
#  Max.   :960   Max.   :1200               1108-node-60 :    10
#                                           (Other)      :609036
#     Size [B]        References     Created [s]      To IB [s]
#  Min.   :   240   Min.   :0.000   Min.   :  20.07   Mode:logical
#  1st Qu.:  1500   1st Qu.:1.000   1st Qu.: 285.04   NA's:609096
#  Median :  1500   Median :2.000   Median : 510.10
#  Mean   :  1596   Mean   :2.128   Mean   : 510.08
#  3rd Qu.:  1500   3rd Qu.:3.000   3rd Qu.: 735.11
#  Max.   :533552   Max.   :8.000   Max.   :1126.08
#
#    To EB [s]        To RB [s]         In RB [s]
#  Min.   : 65.08   Min.   :  54.08   Min.   : 65.1
#  1st Qu.:287.07   1st Qu.: 383.07   1st Qu.:307.1
#  Median :518.08   Median : 552.08   Median :570.1
#  Mean   :532.23   Mean   : 585.37   Mean   :528.5
#  3rd Qu.:749.08   3rd Qu.: 812.08   3rd Qu.:749.1
#  Max.   :971.08   Max.   :1108.08   Max.   :971.1
#  NA's   :5980     NA's   :12230     NA's   :597276

# %%
label <- lifecycle[, unique(paste(`Simulator`, `Variant`, `Network`, `Bandwidth`, `Stage length`, `Max EB size`, `Tx size`, sep=", "))]

# %%
fixed <- c("Simulator", "Variant", "Network", "Bandwidth", "Stage length", "EB rate", "Max EB size", "Tx size")

# %%
varied <- c("Throughput")

# %%
facet_varied <- function(scales="free_y", wide=FALSE) {
    if (wide)
        facet_grid(. ~ `Throughput`, scales=scales)
    else
        facet_grid(`Throughput` ~ ., scales=scales)
}

# %% [markdown]
# #### Range of transaction injection

# %%
txFirst <- lifecycle[, median(`Tx start [s]`)]
txLast <- lifecycle[, median(`Tx stop [s]`)]
txWindow <- txLast - txFirst
simFinish <- lifecycle[, median(`Sim stop [s]`)]

# %%
ggplot(lifecycle, aes(x=`Created [s]`)) +
    geom_histogram(binwidth=5, fill="lightgray") +
    geom_vline(xintercept=txFirst, color="blue") +
    geom_vline(xintercept=txLast, color="red") +
    ylab("Number of Transactions") +
    ggtitle("Time range of Transactions", label)
# Out:
# plot without title

# %% [markdown]
# #### Actual TPS

# %%
dtmp <- lifecycle[
    `Message` == "TX" & `Created [s]` >= txFirst & `Created [s]` <= txLast, 
    .(
        `Demand [tx/s]`=.N/txWindow
    ),
    c(fixed, varied)
]
setorderv(dtmp, varied)
dtmp
# Out:
#   Simulator Variant                   Network     Bandwidth Stage length
# 1 Rust      linear-with-tx-references topology-v2 50 Mb/s   10 slot/stage
# 2 Rust      linear-with-tx-references topology-v2 50 Mb/s   10 slot/stage
# 3 Rust      linear-with-tx-references topology-v2 50 Mb/s   10 slot/stage
# 4 Rust      linear-with-tx-references topology-v2 50 Mb/s   10 slot/stage
# 5 Rust      linear-with-tx-references topology-v2 50 Mb/s   10 slot/stage
#   EB rate      Max EB size Tx size   Throughput   Demand [tx/s]
# 1 2.5 EB/stage 25 MB/EB    1500 B/Tx 0.100 TxMB/s  66.66778
# 2 2.5 EB/stage 25 MB/EB    1500 B/Tx 0.150 TxMB/s 100.00111
# 3 2.5 EB/stage 25 MB/EB    1500 B/Tx 0.200 TxMB/s 142.85778
# 4 2.5 EB/stage 25 MB/EB    1500 B/Tx 0.250 TxMB/s 166.66778
# 5 2.5 EB/stage 25 MB/EB    1500 B/Tx 0.300 TxMB/s 200.00111

# %% [markdown]
# #### Size of persisted data

# %%
ggplot(
    lifecycle[,
        .(`Size [kB/s]`=sum(`Size [B]`)/1e3/600),
        c(varied, "Message")
    ],
    aes(x=!!sym(varied), y=`Size [kB/s]`, fill=`Message`)
) + geom_bar(stat="identity") +
    ggtitle("Size of diffused data", subtitle=label)
# Out:
# plot without title

# %%
ggsave("plots/sizes.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Spatial efficiency

# %%
dtmp <- lifecycle[
        `Message` == "TX", 
        .(`Tx size [B]`=sum(ifelse(is.na(`To RB [s]`) & is.na(`In RB [s]`), 0, 1.0 * `Size [B]`))),
        varied
    ][
        lifecycle[
            , 
            .(`Non-tx size [B]`=sum(as.numeric((`Variant` != "linear" & `Message` == "TX" | `Message` == "EB" | `Message` == "RB") * `Size [B]`))), 
            varied
        ],
        on=varied
    ][, .(`Space efficiency [%]`=100*`Tx size [B]`/`Non-tx size [B]`), varied]
setorderv(dtmp, varied)
dtmp
# Out:
#   Throughput   Space efficiency [%]
# 1 0.100 TxMB/s 92.02115
# 2 0.150 TxMB/s 92.61403
# 3 0.200 TxMB/s 94.13456
# 4 0.250 TxMB/s 94.41841
# 5 0.300 TxMB/s 94.61646

# %%
ggplot(
    lifecycle[
        `Message` == "TX", 
        .(`Tx size [B]`=sum(ifelse(is.na(`To RB [s]`) & is.na(`In RB [s]`), 0, 1.0 * `Size [B]`))),
        varied
    ][
        lifecycle[
            `Message` != "VT", 
            .(`Non-tx size [B]`=sum(as.numeric((`Variant` != "linear" & `Message` == "TX" | `Message` == "EB" | `Message` == "RB") * `Size [B]`))), 
            varied
        ],
        on=varied
    ][, .(`Space efficiency [%]`=100*`Tx size [B]`/`Non-tx size [B]`), varied],
    aes(x=!!sym(varied), y=`Space efficiency [%]`)
) +
    geom_bar(stat="identity") +
    ylim(0, 100) +
    ggtitle("Spatial efficiency (size of txs on ledger / size of non-tx persisted data)", label)
# Out:
# plot without title

# %%
ggsave("plots/spatial-efficiency.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Time to reach the EB

# %%
dtmp <- lifecycle[
        `Message` == "TX" & 
        !is.na(`To EB [s]`) &
        `Created [s]` >= txFirst & `Created [s]` <= txLast, 
        .(`Time to reach EB [s]`=mean(`To EB [s]`-`Created [s]`)), 
        varied
    ]
setorderv(dtmp, varied)
dtmp
# Out:
#   Throughput   Time to reach EB [s]
# 1 0.100 TxMB/s 20.71690
# 2 0.150 TxMB/s 21.79351
# 3 0.200 TxMB/s 22.82799
# 4 0.250 TxMB/s 20.72398
# 5 0.300 TxMB/s 21.96799

# %%
ggplot(
    substitute(
        lifecycle[
            `Message` == "TX" & 
            !is.na(`To EB [s]`) &
            `Created [s]` >= txFirst & `Created [s]` < txLast, 
            .(`Time to reach EB [s]`=(`To EB [s]`-`Created [s]`)), 
            .(`Varied`, `Minute created`=factor(floor(`Created [s]`/60)))
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Time to reach EB [s]`, fill=`Minute created`)
) + geom_histogram(bins=50, position="stack") +
    facet_varied() +
    xlab("Time for transaction to reach EB [s]") +
    ylab("Number of items") +
    ggtitle("Time for transaction to reach an EB", label) +
    theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
# Out:
# plot without title

# %%
ggsave("plots/reach-eb-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Time to reach the ledger

# %%
dtmp <- lifecycle[
        `Message` == "TX" & 
        !is.na(`To RB [s]`) &
        `Created [s]` >= txFirst & `Created [s]` <= txLast, 
        .(`Time to reach ledger [s]`=mean(`To RB [s]`-`Created [s]`)), 
        varied
    ]
setorderv(dtmp, varied)
dtmp
# Out:
#   Throughput   Time to reach ledger [s]
# 1 0.100 TxMB/s 75.08914
# 2 0.150 TxMB/s 79.23122
# 3 0.200 TxMB/s 75.82512
# 4 0.250 TxMB/s 72.26751
# 5 0.300 TxMB/s 73.72165

# %%
ggplot(
    substitute(
        lifecycle[
            `Message` == "TX" & 
            !is.na(`To RB [s]`) &
            `Created [s]` >= txFirst & `Created [s]` < txLast, 
            .(`Time to reach ledger [s]`=`To RB [s]`-`Created [s]`), 
            .(`Varied`, `Minute created`=factor(floor(`Created [s]`/60)))
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Time to reach ledger [s]`, fill=`Minute created`)
) + geom_histogram(bins=50) +
    facet_varied() +
    xlab("Time for transaction to reach ledger [s]") +
    ylab("Number of items") +
    ggtitle("Time for transaction to reach the ledger", label) +
    theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
# Out:
# plot without title

# %%
ggsave("plots/reach-rb-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Number of references
#
# A *reference* is one of the following:
#
# - A transaction is included in an IB.
# - An IB is referenced by an EB.
# - An EB is referenced by another EB.
#
# In an efficient Leios, the number of references for each data item would be one.
#
# - *Zero references* indicates that the item was not used.
# - *Two or more references* indicates that duplication has occurred.

# %%
ggplot(
    lifecycle[
        `Message` == "EB",
        .(`References`),
        varied
    ], 
    aes(x=`References`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
#   scale_x_sqrt() +
    ylab("Number of EB") +
    ggtitle("Number of EB references (0 = not used, 2+ = duplicated)", label)
# Out:
# plot without title

# %%
ggsave("plots/references-tx.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    lifecycle[
        `Message` == "TX",
        .(`References`),
        varied
    ], 
    aes(x=`References`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
    ylab("Number of TX") +
    ggtitle("Number of TX references (0 = not used, 2+ = duplicated)", label)
# Out:
# plot without title

# %%
ggsave("plots/references-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Temporal efficiency

# %%
toElapsed <- function(created, toRb, inRb) {
    if (!is.na(toRb))
        toRb - created
    else if (!is.na(inRb))
        inRb - created
    else
        as.numeric(NA)
}

# %%
outcomes <- lifecycle[
    `Message` == "TX",
    .(
        `Submitted [minute]`=factor(floor(`Created [s]`/60)), 
        `Time to reach ledger [s]`=mapply(toElapsed, `Created [s]`, `To RB [s]`, `In RB [s]`)
    ),
    varied
]

# %%
totals <- substitute(
    outcomes[
        , 
        .(`Total`=.N, `Lost`=sum(is.na(`Time to reach ledger [s]`))), 
        .(`Varied`, `Submitted [minute]`)
    ],
    env=list(`Varied`=sym(varied))
) %>% eval

# %% [markdown]
# #### Transactions reaching the ledger

# %%
ggplot(
    substitute(
        melt(
            totals[, .(`On ledger`=1-`Lost`/`Total`, `Lost`=`Lost`/`Total`), .(`Varied`, `Submitted [minute]`)],
            id.vars=c(varied, "Submitted [minute]"),
            variable.name="Outcome",
            value.name="Fraction"
        )[`Submitted [minute]` != 6, .(
            `Varied`,
            `Submitted [minute]`, 
            `Outcome`=factor(`Outcome`,levels=c("Lost","On ledger")), 
            `Fraction [%]`=100*`Fraction`
        )],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Submitted [minute]`, y=`Fraction [%]`, fill=`Outcome`)
) +
    geom_bar(stat="identity") +
    facet_varied() +
    ggtitle("Transactions reaching the ledger", label) +
    theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
ggsave("plots/temporal-efficiency-bar.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Release memory

# %%
rm(lifecycle, outcomes, totals)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells  963900 51.5  2397291   128.1  2397291 128.1
# Vcells 1840991 14.1 18228133   139.1 22785166 173.9

# %% [markdown]
# ### Resource usage

# %%
if (file.exists("results/resources.Rdata")) {
    load(file="results/resources.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    resources <- fread("results/resources.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(resources, file="results/resources.Rdata")
}
resources[, `Stage length`:=factor(`Stage length`, levels=sort_factors(resources[, unique(`Stage length`)]))]
resources %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#  Simulator                        Variant            Network       Bandwidth
#  Rust:3750   linear-with-tx-references:3750   topology-v2:3750   50 Mb/s:3750
#
#
#
#
#
#
#         Stage length          EB rate       Max EB size        Tx size
#  10 slot/stage:3750   2.5 EB/stage:3750   25 MB/EB:3750   1500 B/Tx:3750
#
#
#
#
#
#
#         Throughput   Tx start [s]  Tx stop [s]   Sim stop [s]        Node
#  0.100 TxMB/s:750   Min.   :60    Min.   :960   Min.   :1200   node-0  :   5
#  0.150 TxMB/s:750   1st Qu.:60    1st Qu.:960   1st Qu.:1200   node-1  :   5
#  0.200 TxMB/s:750   Median :60    Median :960   Median :1200   node-10 :   5
#  0.250 TxMB/s:750   Mean   :60    Mean   :960   Mean   :1200   node-100:   5
#  0.300 TxMB/s:750   3rd Qu.:60    3rd Qu.:960   3rd Qu.:1200   node-101:   5
#                     Max.   :60    Max.   :960   Max.   :1200   node-102:   5
#                                                                (Other) :3720
#    Egress [B]           Disk [B]       Total CPU [s]    Maximum CPU [s/s]
#  Min.   :7.140e+03   Min.   :      0   Min.   : 56.90   Min.   :1.097
#  1st Qu.:1.299e+07   1st Qu.:      0   1st Qu.: 86.31   1st Qu.:1.732
#  Median :1.117e+08   Median :      0   Median :111.09   Median :2.419
#  Mean   :1.876e+08   Mean   :  15800   Mean   :106.92   Mean   :2.226
#  3rd Qu.:2.465e+08   3rd Qu.:      0   3rd Qu.:127.13   3rd Qu.:2.823
#  Max.   :1.779e+09   Max.   :1300320   Max.   :151.30   Max.   :3.013

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `Nodal egress [Mb/s]`=8*`Egress [B]`/simFinish/1e6)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`Nodal egress [Mb/s]`)
) +
    geom_violin() +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("Network", label)
# Out:
# plot without title

# %%
ggsave("plots/network.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `1-Second peak CPU [vCPU⋅s/s]`=`Maximum CPU [s/s]`)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`1-Second peak CPU [vCPU⋅s/s]`)
) +
    geom_boxplot() +
    ylim(0, NA) +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("1-Second Peak CPU", label)
# Out:
# plot without title

# %%
ggsave("plots/cpu-peak.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        resources[, .(`Varied`, `Node`, `Mean CPU [vCPU⋅s/s]`=`Total CPU [s]`/simFinish)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x="", y=`Mean CPU [vCPU⋅s/s]`)
) +
    geom_boxplot() +
    ylim(0, NA) +
    facet_varied(wide=TRUE) +
    xlab("") +
    ggtitle("Mean CPU", label)
# Out:
# plot without title

# %%
ggsave("plots/cpu-mean.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Release memory

# %%
rm(resources)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells  994010 53.1  2397291   128.1  2397291 128.1
# Vcells 1893083 14.5 14582507   111.3 22785166 173.9

# %% [markdown]
# ### Receipt of messages

# %% [markdown]
# #### Read results

# %%
if (file.exists("results/receipts.Rdata")) {
    load("results/receipts.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    receipts <- fread("results/receipts.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(receipts, file="results/receipts.Rdata")
}
setnames(receipts, old="Kind", new="Message")
receipts[, `Stage length`:=factor(`Stage length`, levels=sort_factors(receipts[, unique(`Stage length`)]))]
receipts %>% summary
# Out:
# Loaded Rdata file: sampleSize = 0.5
#  Simulator                             Variant                 Network
#  Rust:246132443   linear-with-tx-references:246132443   topology-v2:246132443
#
#
#
#
#
#
#    Bandwidth                Stage length               EB rate
#  50 Mb/s:246132443   10 slot/stage:246132443   2.5 EB/stage:246132443
#
#
#
#
#
#
#    Max EB size             Tx size                 Throughput
#  25 MB/EB:246132443   1500 B/Tx:246132443   0.100 TxMB/s:26125321
#                                             0.150 TxMB/s:37297365
#                                             0.200 TxMB/s:51808823
#                                             0.250 TxMB/s:59833433
#                                             0.300 TxMB/s:71067501
#
#
#   Tx start [s]  Tx stop [s]   Sim stop [s]  Message
#  Min.   :60    Min.   :960   Min.   :1200   EB:    97032
#  1st Qu.:60    1st Qu.:960   1st Qu.:1200   RB:   122303
#  Median :60    Median :960   Median :1200   TX:227933635
#  Mean   :60    Mean   :960   Mean   :1200   VT: 17979473
#  3rd Qu.:60    3rd Qu.:960   3rd Qu.:1200
#  Max.   :60    Max.   :960   Max.   :1200
#
#             Item               Producer         Generated [s]
#  1078-node-186:     6959   node-748:   538765   Min.   :  20.07
#  26-node-95   :     6895   node-744:   535970   1st Qu.: 289.94
#  1126-node-560:     6625   node-638:   518997   Median : 519.97
#  1040-node-597:     6603   node-615:   497761   Mean   : 517.26
#  1108-node-60 :     6556   node-341:   487216   3rd Qu.: 744.09
#  1119-node-425:     6461   node-442:   462896   Max.   :1129.00
#  (Other)      :246092344   (Other) :243090838
#     Size [B]         Recipient          Received [s]      Elapsed [s]
#  Min.   :   105   node-425:   330071   Min.   :  20.08   Min.   :0.0003
#  1st Qu.:  1500   node-143:   329636   1st Qu.: 290.06   1st Qu.:0.0879
#  Median :  1500   node-98 :   329597   Median : 520.22   Median :0.1270
#  Mean   :  1492   node-487:   329565   Mean   : 517.51   Mean   :0.2505
#  3rd Qu.:  1500   node-574:   329535   3rd Qu.: 744.35   3rd Qu.:0.2992
#  Max.   :533552   node-582:   329329   Max.   :1130.99   Max.   :2.7521
#                   (Other) :244154710

# %%
kinds <- receipts[, unique(`Message`) %>% sort]
kinds
# Out:
# [1] EB RB TX VT
# Levels: EB RB TX VT

# %% [markdown]
# #### Arrival histograms

# %% [markdown]
# ##### Compare the distributions of elapsed times

# %%
arrivalDelayHistogram <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[, .(`Varied`, `Network`, `Elapsed [s]`, `Minute created`=factor(floor(`Generated [s]`/60)))],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Elapsed [s]`, fill=`Minute created`)
    ) +
        geom_histogram(binwidth=0.1) +
        facet_varied(scales=scales) +
        xlab("Time from generation to receipt at node [s]") +
        ylab("Number received") +
        ggtitle(title, subtitle=label) +
        theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
for (k in kinds)
    arrivalDelayHistogram(
        receipts[`Message` == k],
        paste("Arrival delay for", k),
        scales="free_y",
        outfiles=paste0("plots/elapsed-", k, ".png")
    ) %>% print
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# #### Bandwidth usage

# %% [markdown]
# ##### Total network bandwidth

# %%
totalBandwidthPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Gb]`=8*sum(`Size [B]`, rm.na=TRUE)/1e9/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Gb]`, fill=`Message`)
    ) +
        geom_area() +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Total network ingress [Gb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
totalBandwidthPlot(
    receipts,
    "Total bandwidth",
    scales="free_y",
    outfiles=paste0("plots/ingress-total-area.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Bandwidth usage per node

# %%
nodeCount <- receipts[, length(unique(`Recipient`))]
nodeCount
# Out:
# [1] 750

# %%
meanNodalIngressPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Mb/node]`=8*sum(`Size [B]`)/1e6/ifelse(`Network`=="topology-v1",10000,750)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Mb/node]`, fill=`Message`)
    ) +
        geom_area() +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Mean network ingress among nodes [Mb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanNodalIngressPlot(
    receipts, 
    "Mean nodal ingress",
    scales="free_y",
    outfiles=paste0("plots/ingress-average-area.png")
)
# Out:
# plot without title

# %%
peakNodalIngressPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            rs[,
                .(`Size [Mb]`=8*sum(`Size [B]`, rm.na=TRUE)/1e6/sampleSize),
                by=.(`Varied`, `Network`, `Slot`=floor(`Received [s]`), `Message`, `Recipient`)
            ][,
                .(`Size [Mb]`=max(`Size [Mb]`)),
                by=.(`Varied`, `Network`, `Slot`, `Message`)
            ],
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Size [Mb]`, color=`Message`)
    ) +
        geom_point(size=0.5) +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Maximum network ingress among nodes [Mb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakNodalIngressPlot(
    receipts, 
    "Peak nodal ingress",
    outfiles=paste0("plots/ingress-peak-point.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Release memory

# %%
rm(receipts)

# %%
gc()
# Out:
#        used       (Mb)    gc trigger (Mb)    max used    (Mb)
# Ncells    1197071    64.0    2397291   128.1     2397291   128.1
# Vcells 2955916464 22551.9 9636891478 73523.7 11996072440 91522.8

# %% [markdown]
# ### CPU usage

# %% [markdown]
# #### Read results

# %%
if (file.exists("results/cpus.Rdata")) {
    load(file="results/cpus.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    cpus <- fread("results/cpus.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
#   save(cpus, file="results/cpus.Rdata")
}
cpus[, `Stage length`:=factor(`Stage length`, levels=sort_factors(cpus[, unique(`Stage length`)]))]
cpus %>% summary
# Out:
# Loaded Rdata file: sampleSize = 0.5
#  Simulator                             Variant                 Network
#  Rust:246351303   linear-with-tx-references:246351303   topology-v2:246351303
#
#
#
#
#
#
#    Bandwidth                Stage length               EB rate
#  50 Mb/s:246351303   10 slot/stage:246351303   2.5 EB/stage:246351303
#
#
#
#
#
#
#    Max EB size             Tx size                 Throughput
#  25 MB/EB:246351303   1500 B/Tx:246351303   0.100 TxMB/s:26169177
#                                             0.150 TxMB/s:37340782
#                                             0.200 TxMB/s:51852732
#                                             0.250 TxMB/s:59877283
#                                             0.300 TxMB/s:71111329
#
#
#   Tx start [s]  Tx stop [s]   Sim stop [s]       Slot
#  Min.   :60    Min.   :960   Min.   :1200   Min.   :  20.0
#  1st Qu.:60    1st Qu.:960   1st Qu.:1200   1st Qu.: 290.0
#  Median :60    Median :960   Median :1200   Median : 520.0
#  Mean   :60    Mean   :960   Mean   :1200   Mean   : 517.1
#  3rd Qu.:60    3rd Qu.:960   3rd Qu.:1200   3rd Qu.: 744.0
#  Max.   :60    Max.   :960   Max.   :1200   Max.   :1130.0
#
#        Node                Task            Duration [s]
#  node-192:   329893   ValTX  :227932253   Min.   :0.0001481
#  node-500:   329780   ValVote: 17980398   1st Qu.:0.0004284
#  node-139:   329771   ValRB  :   122282   Median :0.0004284
#  node-97 :   329733   ValRH  :    97375   Mean   :0.0008149
#  node-590:   329673   ValEB  :    97335   3rd Qu.:0.0004284
#  node-172:   329625   ValEH  :    97214   Max.   :2.8500342
#  (Other) :244372828   (Other):    24446

# %%
cpusNode <-
    substitute(
        cpus[
            ,
            .(`Duration [s]`=sum(`Duration [s]`)),
            by=.(`Varied`, `Network`, `Node`, `Slot`)
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval

# %%
nodeCount <- cpusNode[, length(unique(`Node`))]
nodeCount
# Out:
# [1] 750

# %% [markdown]
# #### Peak CPU usage

# %% [markdown]
# ##### Histogram

# %%
peakCpuHistogram <- function(cs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*max(`Duration [s]`)),
                by=.(`Varied`, `Network`, `Slot`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Duration [%]`)
    ) +
        geom_histogram(binwidth=10) +
        facet_varied(scales=scales) +
        xlab("Peak CPU load [%]") +
        ylab("Number of slots") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakCpuHistogram(
    cpusNode, 
    "Peak CPU load among all nodes",
    scales="free_y",
    outfiles=paste0("plots/cpu-peak-histogram.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Time series

# %%
peakCpuTimeseries <- function(cs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*mean(`Duration [s]`)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Duration [%]`)) +
        geom_line() +
        facet_varied(scale=scales) +
        xlab("Slot") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakCpuTimeseries(
    cpusNode,
    "Peak CPU load among all nodes",
    outfiles=paste0("plots/cpu-peak-timeseries.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Mean CPU usage

# %% [markdown]
# ##### Histogram

# %%
meanCpuHistogram <- function(cs, nodeSeconds, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*sum(`Duration [s]`)/nodeSeconds/ifelse(`Network` == "topology-v1", 10000, 750)),
                by=.(`Varied`, `Network`, `Task`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x="", fill=`Task`, y=`Duration [%]`)) +
        geom_bar(stat = "identity") +
        facet_varied(wide=TRUE, scales=scales) +
        xlab("") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanCpuHistogram(
    cpus[`Slot` >= txFirst & `Slot` < txLast],
    txWindow * sampleSize, 
    "Mean CPU load among all nodes", 
    scales="free_y",
    outfiles=paste0("plots/cpu-mean-histogram.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Time series

# %%
meanCpuTimeseries <- function(cs, nodeSeconds, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
        substitute(
            cs[,
                .(`Duration [%]`=100*sum(`Duration [s]`)/nodeSeconds/ifelse(`Network`=="topology-v1",10000,750)/sampleSize),
                by=.(`Varied`, `Network`, `Slot`, `Task`)
            ], 
            env=list(`Varied`=sym(varied))
        ) %>% eval,
        aes(x=`Slot`, y=`Duration [%]`, color=`Task`)
    ) +
        geom_point(size=0.25, alpha=0.75) +
        facet_varied(scales=scales) +
        scale_y_sqrt() +
        xlab("Slot") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanCpuTimeseries(
    cpus, 
    sampleSize, 
    "Mean CPU load among all nodes",
    outfiles=paste0("plots/cpu-mean-timeseries.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Release memory

# %%
rm(cpus, cpusNode)

# %%
gc()
# Out:
#        used       (Mb)    gc trigger (Mb)    max used    (Mb)
# Ncells    1012888    54.1    2397291   128.1     2397291   128.1
# Vcells 2095937999 15990.8 7709513183 58819.0 11996072440 91522.8

# %% [markdown]
# ## Block contents

# %% [markdown]
# ### Read data

# %%
sizes <- fread("results/sizes.csv.gz", stringsAsFactors=TRUE)
setnames(sizes, old="Kind", new="Message")
sizes[, `Stage length`:=factor(`Stage length`, levels=sort_factors(sizes[, unique(`Stage length`)]))]
sizes %>% summary
# Out:
#  Simulator                       Variant           Network      Bandwidth
#  Rust:520   linear-with-tx-references:520   topology-v2:520   50 Mb/s:520
#
#
#
#
#
#
#         Stage length         EB rate      Max EB size       Tx size
#  10 slot/stage:520   2.5 EB/stage:520   25 MB/EB:520   1500 B/Tx:520
#
#
#
#
#
#
#         Throughput   Tx start [s]  Tx stop [s]   Sim stop [s]  Message
#  0.100 TxMB/s:104   Min.   :60    Min.   :960   Min.   :1200   EB:260
#  0.150 TxMB/s:104   1st Qu.:60    1st Qu.:960   1st Qu.:1200   RB:260
#  0.200 TxMB/s:104   Median :60    Median :960   Median :1200
#  0.250 TxMB/s:104   Mean   :60    Mean   :960   Mean   :1200
#  0.300 TxMB/s:104   3rd Qu.:60    3rd Qu.:960   3rd Qu.:1200
#                     Max.   :60    Max.   :960   Max.   :1200
#
#             Item     Generated [s]      Transactions            Endorses
#  100-node-432 : 10   Min.   :  20.07   Min.   :    0   1040-node-597:  5
#  1040-node-597: 10   1st Qu.: 364.07   1st Qu.:   60   105-node-598 :  5
#  105-node-598 : 10   Median : 603.58   Median :   60   1088-node-151:  5
#  1078-node-186: 10   Mean   : 599.98   Mean   : 2493   131-node-573 :  5
#  1088-node-151: 10   3rd Qu.: 857.33   3rd Qu.: 4501   177-node-149 :  5
#  1108-node-60 : 10   Max.   :1126.08   Max.   :16666   (Other)      : 86
#  (Other)      :460                                     NA's         :409

# %% [markdown]
# ### EB contents

# %% [markdown]
# #### Transactions

# %%
ggplot(sizes[`Message` == "EB"], aes(x=`Transactions`)) +
    geom_histogram(binwidth=1000) +
    facet_varied() +
    ylab("Number of EBs") +
    ggtitle("Number of transactions in EBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-ebs-txs.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
    substitute(
        sizes[`Message` == "EB", .(`EB size [MB]`=`Transactions`*1400/1e6), .(`Varied`, `Network`)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`EB size [MB]`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
    ylab("Number of EBs") +
    ggtitle("Size of transactions in EBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-ebs-size.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# ### RB contents

# %% [markdown]
# #### Transactions

# %%
ggplot(sizes[`Message` == "RB"], aes(x=`Transactions`)) +
    geom_histogram(binwidth=10) +
    facet_varied() +
    ylab("Number of RBs") +
    ggtitle("Number of transactions in RBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-rbs-txs.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
    substitute(
        sizes[`Message` == "RB", .(`RB size [kB]`=`Transactions`*1400/1e3), .(`Varied`, `Network`)],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`RB size [kB]`)
) +
    geom_histogram(binwidth=10) +
    facet_varied() +
    ylab("Number of RBs") +
    ggtitle("Size of transactions in RBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-rbs-size.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# ### Disposition of blocks

# %% [markdown]
# #### Data processing

# %%
ebSizes <- 
    substitute(
        sizes[`Message` == "RB" & !is.na(`Endorses`), .(`Certified`=TRUE), .(`Varied`, `Item`=`Endorses`)][
        sizes[`Message` == "EB", .(`EB Transactions`=`Transactions`), .(`Varied`, `Item`)], 
            on=c(varied, "Item")
        ][
            ,
            .(
                `EB txs later not certified`=ifelse(is.na(`Certified`), as.numeric(`EB Transactions`), 0),
                `EB txs later certified`=ifelse(is.na(`Certified`), 0, as.numeric(`EB Transactions`))
            ),
            .(`Varied`, `Item`)
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval

# %%
rbSizes <- 
    substitute(
        ebSizes[
            ebSizes[, .(`EB txs certified now`=`EB txs later certified`), .(`Varied`, `Endorses`=`Item`)][
                sizes[`Message` == "RB", .(`Generated [s]`, `RB Transactions`=as.numeric(`Transactions`)), .(`Varied`, `Item`, `Endorses`)],
                on=c(varied, "Endorses")
            ],
            on=c(varied, "Item")
        ][
            ,
            .(
                `Generated [s]`,
                `RB`=`RB Transactions`,
                `EB later not certified`=`EB txs later not certified`,
                `EB later certified`=`EB txs later certified`,
                `EB now certified`=ifelse(is.na(`EB txs certified now`), 0, `EB txs certified now`)
            ),
            , .(`Varied`, `Item`)
        ],
        env=list(`Varied`=sym(varied))
    ) %>% eval

# %%
blocks <- melt(
    rbSizes, 
    id.vars=c(varied, "Item", "Generated [s]"),
    measure.vars=c("RB", "EB later not certified", "EB later certified", "EB now certified"),
    variable.name="Block",
    value.name="Transactions"
)

# %% [markdown]
# #### Sanity checks

# %%
ebSizes[, .N] == sizes[`Message` == "EB", .N]
# Out:
# [1] TRUE

# %%
ebSizes[, sum(`EB txs later not certified`) + sum(`EB txs later certified`)] == sizes[`Message` == "EB", sum(`Transactions`)]
# Out:
# [1] TRUE

# %%
rbSizes[, .N] == sizes[`Message` == "RB", .N]
# Out:
# [1] TRUE

# %%
rbSizes[, sum(`RB`)] == sizes[`Message` == "RB", sum(`Transactions`)]
# Out:
# [1] TRUE

# %%
rbSizes[, sum(`EB later not certified`) + sum(`EB later certified`)] == sizes[`Message` == "EB", sum(`Transactions`)]
# Out:
# [1] TRUE

# %%
# TODO: Compute precise equality that accounts for forks.
rbSizes[, sum(`EB later certified`)] <= rbSizes[, sum(`EB now certified`)]
# Out:
# [1] TRUE

# %% [markdown]
# #### Transactions

# %%
ggplot(
    substitute(
        blocks[, .(`Transactions`=sum(`Transactions`)), .(`Varied`, `Block`, `Minute generated`=(floor(`Generated [s]`/60)))],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Minute generated`, y=`Transactions`, fill=`Block`)
) +
    geom_bar(stat="identity") +
    facet_varied()
# Out:
# plot without title

# %%
ggsave("plots/disposition-txs-timeseries.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        blocks[, .(`Transactions`=sum(`Transactions`)), .(`Varied`, `Block`)],
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=!!sym(varied), y=`Transactions`, fill=`Block`)
) +
    geom_bar(stat="identity")
# Out:
# plot without title

# %%
ggsave("plots/disposition-txs-histogram.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
    substitute(
        blocks[, .(`Total size of transactions [MB]`=sum(`Transactions`)*300/1e6), .(`Varied`, `Block`, `Minute of block generation`=(floor(`Generated [s]`/60)))], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=`Minute of block generation`, y=`Total size of transactions [MB]`, fill=`Block`)
) +
    geom_bar(stat="identity") +
    facet_varied() +
    ggtitle("Disposition of transactions in blocks", label)
# Out:
# plot without title

# %%
ggsave("plots/disposition-size-timeseries.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    substitute(
        blocks[, .(`Total size of transactions [MB]`=sum(`Transactions`)*300/1e6), .(`Varied`, `Block`)], 
        env=list(`Varied`=sym(varied))
    ) %>% eval,
    aes(x=!!sym(varied), y=`Total size of transactions [MB]`, fill=`Block`)
) +
    geom_bar(stat="identity") +
    ggtitle("Disposition of transactions", label)
# Out:
# plot without title

# %%
ggsave("plots/disposition-size-histogram.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# # Leios simulation analysis at tag `leios-2025w33`

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Load packages

# %%
suppressMessages({
    require(RColorBrewer, quietly=TRUE)
    require(data.table, quietly=TRUE)
    require(ggplot2, quietly=TRUE)
    require(magrittr, quietly=TRUE)
})

# %% [markdown]
# ### Define utility functions

# %%
sort_factors <- function(fs, ascending=TRUE) {
    xs <- fs[as.numeric(sub(" .*$", "", fs)) %>% order]
    if (ascending)
        xs
    else
        rev(xs)
}

# %% [markdown]
# ## Experiment: Attacks

# %% [markdown]
# ### Analysis of lifecycles and efficiencies

# %% [markdown]
# #### Read the lifecycle results

# %%
if (file.exists("results/lifecycle.Rdata")) {
    load(file="results/lifecycle.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    lifecycle <- fread("results/lifecycle.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
    save(lifecycle, sampleSize, file="results/lifecycle.R")
    cat(paste("Saved Rdata file: sampleSize =", sampleSize, "\n"))
}
setnames(lifecycle, old="Kind", new="Message")
lifecycle %>% summary
# Out:
# Loaded Rdata file: sampleSize = 1
#  Simulator            Propagation            Network          Bandwidth
#  Rust:2302506   eb-received :758492   topology-v2:2302506   50 Mb/s:2302506
#                 fully-valid :771990
#                 txs-received:772024
#
#
#
#
#           CPU                 Diffusion duration          Voting duration
#  4 vCPU/node:2302506   L_diff = 0 slots:1143148   L_vote = 7 slots:2302506
#                        L_diff = 7 slots:1159358
#
#
#
#
#
#    Max EB size              Adversary                      EB delay
#  12 MB/EB:2302506   33% adversary:2302506   EB attack: 6.0 s/EB:1129608
#                                             EB attack: none    :1172898
#
#
#
#
#
#            Tx attack            Tx size               Throughput
#  Tx attack: 100%:1221230   1500 B/Tx:2302506   0.150 TxMB/s:2302506
#  Tx attack: none:1081276
#
#
#
#
#
#   Tx start [s]  Tx stop [s]   Sim stop [s]  Message                Item
#  Min.   :60    Min.   :960   Min.   :1200   EB:   1265   100-node-432:     48
#  1st Qu.:60    1st Qu.:960   1st Qu.:1200   RB:   1265   105-node-598:     48
#  Median :60    Median :960   Median :1200   TX:2299976   131-node-573:     48
#  Mean   :60    Mean   :960   Mean   :1200                177-node-149:     48
#  3rd Qu.:60    3rd Qu.:960   3rd Qu.:1200                20-node-220 :     48
#  Max.   :60    Max.   :960   Max.   :1200                219-node-475:     48
#                                                          (Other)     :2302218
#     Size [B]        References     Created [s]      To IB [s]
#  Min.   :   240   Min.   :0.000   Min.   :  20.07   Mode:logical
#  1st Qu.:  1500   1st Qu.:2.000   1st Qu.: 292.27   NA's:2302506
#  Median :  1500   Median :2.000   Median : 524.59
#  Mean   :  1621   Mean   :2.588   Mean   : 513.59
#  3rd Qu.:  1500   3rd Qu.:3.000   3rd Qu.: 741.09
#  Max.   :256240   Max.   :9.000   Max.   :1195.08
#
#    To EB [s]         To RB [s]         In RB [s]
#  Min.   :  65.08   Min.   :  54.08   Min.   :  65.1
#  1st Qu.: 296.07   1st Qu.: 383.08   1st Qu.: 393.1
#  Median : 552.08   Median : 591.08   Median : 591.1
#  Mean   : 537.86   Mean   : 579.45   Mean   : 577.6
#  3rd Qu.: 749.08   3rd Qu.: 773.08   3rd Qu.: 812.1
#  Max.   :1126.08   Max.   :1195.08   Max.   :1144.1
#  NA's   :10747     NA's   :51593     NA's   :2241081

# %%
label <- lifecycle[, unique(paste(`Simulator`, `Network`, `Bandwidth`, `CPU`, `Voting duration`, `Max EB size`, `Tx size`, `Throughput`, `Adversary`, sep=", "))]
label
# Out:
# [1] "Rust, topology-v2, 50 Mb/s, 4 vCPU/node, L_vote = 7 slots, 12 MB/EB, 1500 B/Tx, 0.150 TxMB/s, 33% adversary"

# %%
fixed <- c("Simulator", "Network", "Bandwidth", "CPU", "Voting duration", "Max EB size", "Tx size", "Throughput", "Adversary")

# %%
variedX <- c("EB delay", "Tx attack")

# %%
variedY <- c("Propagation", "Diffusion duration")

# %%
varied <- c(variedY, variedX)

# %%
lifecycle[, `:=`(
    `VariedX`=factor(paste(`EB delay`, `Tx attack`, sep="\n"), levels=lifecycle[,.N,.(`EB delay`,`Tx attack`)][order(-`EB delay`,-`Tx attack`)][,unique(paste(`EB delay`, `Tx attack`, sep="\n"))]),
    `VariedY`=factor(paste(`Propagation`, `Diffusion duration`, sep="\n"))
)]

# %%
facet_varied <- function(scales="fixed", wide=FALSE) {
    if (wide)
        facet_grid(`VariedY` ~ `VariedX`, scales=scales)
    else
        facet_grid(`VariedX` ~ `VariedY`, scales=scales)
}

# %% [markdown]
# #### Range of transaction injection

# %%
txFirst <- lifecycle[, median(`Tx start [s]`)]
txLast <- lifecycle[, median(`Tx stop [s]`)]
txWindow <- txLast - txFirst
simFinish <- lifecycle[, median(`Sim stop [s]`)]

# %%
ggplot(lifecycle, aes(x=`Created [s]`)) +
    geom_histogram(binwidth=5, fill="lightgray") +
    geom_vline(xintercept=txFirst, color="blue") +
    geom_vline(xintercept=txLast, color="red") +
    ylab("Number of Transactions") +
    ggtitle("Time range of Transactions", label)
# Out:
# plot without title

# %% [markdown]
# #### Actual TPS

# %%
dtmp <- lifecycle[
    `Message` == "TX" & `Created [s]` >= txFirst & `Created [s]` <= txLast, 
    .(
        `Demand [tx/s]`=.N/txWindow
    ),
    c(fixed, varied)
]
setorderv(dtmp, varied)
dtmp
# Out:
#    Simulator Network     Bandwidth CPU         Voting duration  Max EB size
# 1  Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 2  Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 3  Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 4  Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 5  Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 6  Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 7  Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 8  Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 9  Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 10 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 11 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 12 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 13 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 14 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 15 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 16 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 17 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 18 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 19 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 20 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 21 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 22 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 23 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
# 24 Rust      topology-v2 50 Mb/s   4 vCPU/node L_vote = 7 slots 12 MB/EB
#    Tx size   Throughput   Adversary     Propagation  Diffusion duration
# 1  1500 B/Tx 0.150 TxMB/s 33% adversary eb-received  L_diff = 0 slots
# 2  1500 B/Tx 0.150 TxMB/s 33% adversary eb-received  L_diff = 0 slots
# 3  1500 B/Tx 0.150 TxMB/s 33% adversary eb-received  L_diff = 0 slots
# 4  1500 B/Tx 0.150 TxMB/s 33% adversary eb-received  L_diff = 0 slots
# 5  1500 B/Tx 0.150 TxMB/s 33% adversary eb-received  L_diff = 7 slots
# 6  1500 B/Tx 0.150 TxMB/s 33% adversary eb-received  L_diff = 7 slots
# 7  1500 B/Tx 0.150 TxMB/s 33% adversary eb-received  L_diff = 7 slots
# 8  1500 B/Tx 0.150 TxMB/s 33% adversary eb-received  L_diff = 7 slots
# 9  1500 B/Tx 0.150 TxMB/s 33% adversary fully-valid  L_diff = 0 slots
# 10 1500 B/Tx 0.150 TxMB/s 33% adversary fully-valid  L_diff = 0 slots
# 11 1500 B/Tx 0.150 TxMB/s 33% adversary fully-valid  L_diff = 0 slots
# 12 1500 B/Tx 0.150 TxMB/s 33% adversary fully-valid  L_diff = 0 slots
# 13 1500 B/Tx 0.150 TxMB/s 33% adversary fully-valid  L_diff = 7 slots
# 14 1500 B/Tx 0.150 TxMB/s 33% adversary fully-valid  L_diff = 7 slots
# 15 1500 B/Tx 0.150 TxMB/s 33% adversary fully-valid  L_diff = 7 slots
# 16 1500 B/Tx 0.150 TxMB/s 33% adversary fully-valid  L_diff = 7 slots
# 17 1500 B/Tx 0.150 TxMB/s 33% adversary txs-received L_diff = 0 slots
# 18 1500 B/Tx 0.150 TxMB/s 33% adversary txs-received L_diff = 0 slots
# 19 1500 B/Tx 0.150 TxMB/s 33% adversary txs-received L_diff = 0 slots
# 20 1500 B/Tx 0.150 TxMB/s 33% adversary txs-received L_diff = 0 slots
# 21 1500 B/Tx 0.150 TxMB/s 33% adversary txs-received L_diff = 7 slots
# 22 1500 B/Tx 0.150 TxMB/s 33% adversary txs-received L_diff = 7 slots
# 23 1500 B/Tx 0.150 TxMB/s 33% adversary txs-received L_diff = 7 slots
# 24 1500 B/Tx 0.150 TxMB/s 33% adversary txs-received L_diff = 7 slots
#    EB delay            Tx attack       Demand [tx/s]
# 1  EB attack: 6.0 s/EB Tx attack: 100% 107.4556
# 2  EB attack: 6.0 s/EB Tx attack: none 100.0011
# 3  EB attack: none     Tx attack: 100% 110.4578
# 4  EB attack: none     Tx attack: none 100.0011
# 5  EB attack: 6.0 s/EB Tx attack: 100% 110.4578
# 6  EB attack: 6.0 s/EB Tx attack: none 100.0011
# 7  EB attack: none     Tx attack: 100% 113.4600
# 8  EB attack: none     Tx attack: none 100.0011
# 9  EB attack: 6.0 s/EB Tx attack: 100% 107.4556
# 10 EB attack: 6.0 s/EB Tx attack: none 100.0011
# 11 EB attack: none     Tx attack: 100% 116.4622
# 12 EB attack: none     Tx attack: none 100.0011
# 13 EB attack: 6.0 s/EB Tx attack: 100% 110.4578
# 14 EB attack: 6.0 s/EB Tx attack: none 100.0011
# 15 EB attack: none     Tx attack: 100% 122.4667
# 16 EB attack: none     Tx attack: none 100.0011
# 17 EB attack: 6.0 s/EB Tx attack: 100% 107.4556
# 18 EB attack: 6.0 s/EB Tx attack: none 100.0011
# 19 EB attack: none     Tx attack: 100% 119.4644
# 20 EB attack: none     Tx attack: none 100.0011
# 21 EB attack: 6.0 s/EB Tx attack: 100% 110.4578
# 22 EB attack: 6.0 s/EB Tx attack: none 100.0011
# 23 EB attack: none     Tx attack: 100% 119.4644
# 24 EB attack: none     Tx attack: none 100.0011

# %% [markdown]
# #### Size of persisted data

# %%
ggplot(
    lifecycle[,
        .(`Size [kB/s]`=sum(`Size [B]`)/1e3/600),
        c("VariedX", "VariedY", "Message")
    ],
    aes(x="", y=`Size [kB/s]`, fill=`Message`)
) + geom_bar(stat="identity") +
    facet_varied(scales="fixed") +
    ggtitle("Size of diffused data", subtitle=label)
# Out:
# plot without title

# %%
ggsave("plots/sizes.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Spatial efficiency

# %%
dtmp <- lifecycle[
        `Message` == "TX", 
        .(`Tx size [B]`=sum(ifelse(is.na(`To RB [s]`) & is.na(`In RB [s]`), 0, 1.0 * `Size [B]`))),
        varied
    ][
        lifecycle[
            , 
            .(`Non-tx size [B]`=sum(as.numeric((`Message` == "TX" | `Message` == "EB" | `Message` == "RB") * `Size [B]`))), 
            varied
        ],
        on=varied
    ][, .(`Space efficiency [%]`=100*`Tx size [B]`/`Non-tx size [B]`), varied]
setorderv(dtmp, varied)
dtmp
# Out:
#    Propagation  Diffusion duration EB delay            Tx attack
# 1  eb-received  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 2  eb-received  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: none
# 3  eb-received  L_diff = 0 slots   EB attack: none     Tx attack: 100%
# 4  eb-received  L_diff = 0 slots   EB attack: none     Tx attack: none
# 5  eb-received  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 6  eb-received  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: none
# 7  eb-received  L_diff = 7 slots   EB attack: none     Tx attack: 100%
# 8  eb-received  L_diff = 7 slots   EB attack: none     Tx attack: none
# 9  fully-valid  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 10 fully-valid  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: none
# 11 fully-valid  L_diff = 0 slots   EB attack: none     Tx attack: 100%
# 12 fully-valid  L_diff = 0 slots   EB attack: none     Tx attack: none
# 13 fully-valid  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 14 fully-valid  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: none
# 15 fully-valid  L_diff = 7 slots   EB attack: none     Tx attack: 100%
# 16 fully-valid  L_diff = 7 slots   EB attack: none     Tx attack: none
# 17 txs-received L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 18 txs-received L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: none
# 19 txs-received L_diff = 0 slots   EB attack: none     Tx attack: 100%
# 20 txs-received L_diff = 0 slots   EB attack: none     Tx attack: none
# 21 txs-received L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 22 txs-received L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: none
# 23 txs-received L_diff = 7 slots   EB attack: none     Tx attack: 100%
# 24 txs-received L_diff = 7 slots   EB attack: none     Tx attack: none
#    Space efficiency [%]
# 1  88.60258
# 2  93.18226
# 3  93.54705
# 4  92.87637
# 5  88.56721
# 6  92.19450
# 7  92.43859
# 8  91.94985
# 9  91.89644
# 10 91.36802
# 11 92.95009
# 12 92.73770
# 13 77.37280
# 14 89.71509
# 15 91.62396
# 16 92.16546
# 17 93.41244
# 18 93.06316
# 19 93.32065
# 20 92.58873
# 21 93.03583
# 22 92.22793
# 23 92.16699
# 24 92.19741

# %%
lifecycle[
            `Message` != "VT", 
            .(`Non-tx size [B]`=sum(as.numeric((`Message` == "TX" | `Message` == "EB" | `Message` == "RB") * `Size [B]`))), 
            .(`VariedX`, `VariedY`)
        ]
# Out:
#    VariedX                              VariedY
# 1  EB attack: none\nTx attack: none     eb-received\nL_diff = 0 slots
# 2  EB attack: none\nTx attack: 100%     eb-received\nL_diff = 0 slots
# 3  EB attack: 6.0 s/EB\nTx attack: none eb-received\nL_diff = 0 slots
# 4  EB attack: 6.0 s/EB\nTx attack: 100% eb-received\nL_diff = 0 slots
# 5  EB attack: none\nTx attack: none     eb-received\nL_diff = 7 slots
# 6  EB attack: none\nTx attack: 100%     eb-received\nL_diff = 7 slots
# 7  EB attack: 6.0 s/EB\nTx attack: none eb-received\nL_diff = 7 slots
# 8  EB attack: 6.0 s/EB\nTx attack: 100% eb-received\nL_diff = 7 slots
# 9  EB attack: none\nTx attack: none     txs-received\nL_diff = 0 slots
# 10 EB attack: none\nTx attack: 100%     txs-received\nL_diff = 0 slots
# 11 EB attack: 6.0 s/EB\nTx attack: none txs-received\nL_diff = 0 slots
# 12 EB attack: 6.0 s/EB\nTx attack: 100% txs-received\nL_diff = 0 slots
# 13 EB attack: none\nTx attack: none     txs-received\nL_diff = 7 slots
# 14 EB attack: none\nTx attack: 100%     txs-received\nL_diff = 7 slots
# 15 EB attack: 6.0 s/EB\nTx attack: none txs-received\nL_diff = 7 slots
# 16 EB attack: 6.0 s/EB\nTx attack: 100% txs-received\nL_diff = 7 slots
# 17 EB attack: none\nTx attack: none     fully-valid\nL_diff = 0 slots
# 18 EB attack: none\nTx attack: 100%     fully-valid\nL_diff = 0 slots
# 19 EB attack: 6.0 s/EB\nTx attack: none fully-valid\nL_diff = 0 slots
# 20 EB attack: 6.0 s/EB\nTx attack: 100% fully-valid\nL_diff = 0 slots
# 21 EB attack: none\nTx attack: none     fully-valid\nL_diff = 7 slots
# 22 EB attack: none\nTx attack: 100%     fully-valid\nL_diff = 7 slots
# 23 EB attack: 6.0 s/EB\nTx attack: none fully-valid\nL_diff = 7 slots
# 24 EB attack: 6.0 s/EB\nTx attack: 100% fully-valid\nL_diff = 7 slots
#    Non-tx size [B]
# 1  145356140
# 2  159404272
# 3  144878972
# 4  154834096
# 5  146820796
# 6  165700280
# 7  146431180
# 8  159668564
# 9  145807708
# 10 172820264
# 11 145064380
# 12 155295160
# 13 146426572
# 14 174983464
# 15 146378108
# 16 160280192
# 17 145573484
# 18 169148832
# 19 147755740
# 20 157857032
# 21 146477324
# 22 180444064
# 23 150478028
# 24 164966896

# %%
ggplot(
    lifecycle[
        `Message` == "TX", 
        .(`Tx size [B]`=sum(ifelse(is.na(`To RB [s]`) & is.na(`In RB [s]`), 0, 1.0 * `Size [B]`))),
        .(`VariedX`, `VariedY`)
    ][
        lifecycle[
            `Message` != "VT", 
            .(`Non-tx size [B]`=sum(as.numeric((`Message` == "TX" | `Message` == "EB" | `Message` == "RB") * `Size [B]`))), 
            .(`VariedX`, `VariedY`)
        ],
        on=c("VariedX", "VariedY")
    ][, .(`Space efficiency [%]`=100*`Tx size [B]`/`Non-tx size [B]`), .(`VariedX`, `VariedY`)],
    aes(x="", y=`Space efficiency [%]`)
) +
    geom_bar(stat="identity") +
    facet_varied(scales="fixed") +
    ylim(0, 100) +
    ggtitle("Spatial efficiency (size of txs on ledger / size of non-tx persisted data)", label)
# Out:
# plot without title

# %%
ggsave("plots/spatial-efficiency.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Time to reach the EB

# %%
dtmp <- lifecycle[
        `Message` == "TX" & 
        !is.na(`To EB [s]`) &
        `Created [s]` >= txFirst & `Created [s]` <= txLast, 
        .(`Time to reach EB [s]`=mean(`To EB [s]`-`Created [s]`)), 
        varied
    ]
setorderv(dtmp, varied)
dtmp
# Out:
#    Propagation  Diffusion duration EB delay            Tx attack
# 1  eb-received  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 2  eb-received  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: none
# 3  eb-received  L_diff = 0 slots   EB attack: none     Tx attack: 100%
# 4  eb-received  L_diff = 0 slots   EB attack: none     Tx attack: none
# 5  eb-received  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 6  eb-received  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: none
# 7  eb-received  L_diff = 7 slots   EB attack: none     Tx attack: 100%
# 8  eb-received  L_diff = 7 slots   EB attack: none     Tx attack: none
# 9  fully-valid  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 10 fully-valid  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: none
# 11 fully-valid  L_diff = 0 slots   EB attack: none     Tx attack: 100%
# 12 fully-valid  L_diff = 0 slots   EB attack: none     Tx attack: none
# 13 fully-valid  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 14 fully-valid  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: none
# 15 fully-valid  L_diff = 7 slots   EB attack: none     Tx attack: 100%
# 16 fully-valid  L_diff = 7 slots   EB attack: none     Tx attack: none
# 17 txs-received L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 18 txs-received L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: none
# 19 txs-received L_diff = 0 slots   EB attack: none     Tx attack: 100%
# 20 txs-received L_diff = 0 slots   EB attack: none     Tx attack: none
# 21 txs-received L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 22 txs-received L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: none
# 23 txs-received L_diff = 7 slots   EB attack: none     Tx attack: 100%
# 24 txs-received L_diff = 7 slots   EB attack: none     Tx attack: none
#    Time to reach EB [s]
# 1  15.06735
# 2  22.65309
# 3  14.09064
# 4  24.10692
# 5  15.20607
# 6  24.38541
# 7  18.51422
# 8  24.68271
# 9  25.63898
# 10 30.84465
# 11 16.16756
# 12 22.72927
# 13 54.02914
# 14 90.56148
# 15 28.52943
# 16 24.68583
# 17 15.51601
# 18 23.47322
# 19 12.79605
# 20 22.49277
# 21 17.38715
# 22 24.99220
# 23 18.97169
# 24 25.94284

# %%
ggplot(
        lifecycle[
            `Message` == "TX" & 
            !is.na(`To EB [s]`) &
            `Created [s]` >= txFirst & `Created [s]` < txLast, 
            .(`Time to reach EB [s]`=(`To EB [s]`-`Created [s]`)), 
            .(`VariedX`, `VariedY`, `Minute created`=factor(floor(`Created [s]`/60)))
        ],
    aes(x=`Time to reach EB [s]`, fill=`Minute created`)
) + geom_histogram(bins=50, position="stack") +
    facet_varied() +
    xlab("Time for transaction to reach EB [s]") +
    ylab("Number of items") +
    ggtitle("Time for transaction to reach an EB", label) +
    theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
# Out:
# plot without title

# %%
ggsave("plots/reach-eb-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Time to reach the ledger

# %%
dtmp <- lifecycle[
        `Message` == "TX" & 
        !is.na(`To RB [s]`) &
        `Created [s]` >= txFirst & `Created [s]` <= txLast, 
        .(`Time to reach ledger [s]`=mean(`To RB [s]`-`Created [s]`)), 
        varied
    ]
setorderv(dtmp, varied)
dtmp
# Out:
#    Propagation  Diffusion duration EB delay            Tx attack
# 1  eb-received  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 2  eb-received  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: none
# 3  eb-received  L_diff = 0 slots   EB attack: none     Tx attack: 100%
# 4  eb-received  L_diff = 0 slots   EB attack: none     Tx attack: none
# 5  eb-received  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 6  eb-received  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: none
# 7  eb-received  L_diff = 7 slots   EB attack: none     Tx attack: 100%
# 8  eb-received  L_diff = 7 slots   EB attack: none     Tx attack: none
# 9  fully-valid  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 10 fully-valid  L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: none
# 11 fully-valid  L_diff = 0 slots   EB attack: none     Tx attack: 100%
# 12 fully-valid  L_diff = 0 slots   EB attack: none     Tx attack: none
# 13 fully-valid  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 14 fully-valid  L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: none
# 15 fully-valid  L_diff = 7 slots   EB attack: none     Tx attack: 100%
# 16 fully-valid  L_diff = 7 slots   EB attack: none     Tx attack: none
# 17 txs-received L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 18 txs-received L_diff = 0 slots   EB attack: 6.0 s/EB Tx attack: none
# 19 txs-received L_diff = 0 slots   EB attack: none     Tx attack: 100%
# 20 txs-received L_diff = 0 slots   EB attack: none     Tx attack: none
# 21 txs-received L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: 100%
# 22 txs-received L_diff = 7 slots   EB attack: 6.0 s/EB Tx attack: none
# 23 txs-received L_diff = 7 slots   EB attack: none     Tx attack: 100%
# 24 txs-received L_diff = 7 slots   EB attack: none     Tx attack: none
#    Time to reach ledger [s]
# 1   50.69842
# 2   52.65633
# 3   41.55546
# 4   56.03596
# 5   59.98167
# 6   64.49120
# 7   65.79174
# 8   64.09703
# 9   80.16056
# 10  80.83244
# 11  51.48919
# 12  53.60776
# 13 157.94819
# 14 158.21992
# 15  97.70698
# 16  64.36274
# 17  51.88756
# 18  54.64204
# 19  39.11796
# 20  51.39454
# 21  61.53882
# 22  65.08873
# 23  63.65356
# 24  67.35180

# %%
ggplot(
        lifecycle[
            `Message` == "TX" & 
            !is.na(`To RB [s]`) &
            `Created [s]` >= txFirst & `Created [s]` < txLast, 
            .(`Time to reach ledger [s]`=`To RB [s]`-`Created [s]`), 
            .(`VariedX`, `VariedY`, `Minute created`=factor(floor(`Created [s]`/60)))
        ],
    aes(x=`Time to reach ledger [s]`, fill=`Minute created`)
) + geom_histogram(bins=50) +
    facet_varied() +
    xlab("Time for transaction to reach ledger [s]") +
    ylab("Number of items") +
    ggtitle("Time for transaction to reach the ledger", label) +
    theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
# Out:
# plot without title

# %%
ggsave("plots/reach-rb-tx.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
        lifecycle[
            `Message` == "TX" & 
            !is.na(`To RB [s]`) &
            `Created [s]` >= txFirst & `Created [s]` < txLast, 
            .(`Time to reach ledger [s]`=`To RB [s]`-`Created [s]`), 
            .(`VariedX`, `VariedY`, `Minute created`=factor(floor(`Created [s]`/60)))
        ],
    aes(x=`Time to reach ledger [s]`, fill=`Minute created`)
) + geom_histogram(bins=50) +
    facet_varied() +
    xlab("Time for transaction to reach ledger [s]") +
    ylab("Number of items") +
    ggtitle("Time for transaction to reach the ledger", label) +
    theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
# Out:
# plot without title

# %%
ggsave("plots/reach-rb-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Number of references
#
# A *reference* is one of the following:
#
# - A transaction is included in an IB.
# - An IB is referenced by an EB.
# - An EB is referenced by another EB.
#
# In an efficient Leios, the number of references for each data item would be one.
#
# - *Zero references* indicates that the item was not used.
# - *Two or more references* indicates that duplication has occurred.

# %%
ggplot(
    lifecycle[
        `Message` == "EB",
        .(`References`),
        .(`VariedX`, `VariedY`)
    ], 
    aes(x=`References`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
#   scale_x_sqrt() +
    ylab("Number of EB") +
    ggtitle("Number of EB references (0 = not used, 2+ = duplicated)", label)
# Out:
# plot without title

# %%
ggsave("plots/references-tx.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
    lifecycle[
        `Message` == "TX",
        .(`References`),
        .(`VariedX`, `VariedY`)
    ], 
    aes(x=`References`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
    ylab("Number of TX") +
    ggtitle("Number of TX references (0 = not used, 2+ = duplicated)", label)
# Out:
# plot without title

# %%
ggsave("plots/references-tx.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Temporal efficiency

# %%
toElapsed <- function(created, toRb, inRb) {
    if (!is.na(toRb))
        toRb - created
    else if (!is.na(inRb))
        inRb - created
    else
        as.numeric(NA)
}

# %%
outcomes <- lifecycle[
    `Message` == "TX" & `Created [s]` < txLast,
    .(
        `Submitted [minute]`=factor(floor(`Created [s]`/60)), 
        `Time to reach ledger [s]`=mapply(toElapsed, `Created [s]`, `To RB [s]`, `In RB [s]`)
    ),
    .(`VariedX`, `VariedY`)
]

# %%
totals <- 
    outcomes[
        , 
        .(
            `Total`=.N, 
            `Lost`=sum(is.na(`Time to reach ledger [s]`)),
            `1st min`=sum(`Time to reach ledger [s]`<=60,na.rm=TRUE),
            `2nd min`=sum(`Time to reach ledger [s]`>60&`Time to reach ledger [s]`<=120,na.rm=TRUE),
            `3rd min`=sum(`Time to reach ledger [s]`>120&`Time to reach ledger [s]`<=180,na.rm=TRUE)
        ), 
        .(`VariedX`, `VariedY`, `Submitted [minute]`)
    ]

# %% [markdown]
# #### Transactions reaching the ledger

# %%
ggplot(
        melt(
            totals[
                , 
                .(
                    `Ledger in 1st min`=`1st min`/`Total`, 
                    `Ledger in 2nd min`=`2nd min`/`Total`, 
                    `Ledger in 3rd min`=`3rd min`/`Total`, 
                    `Ledger later`=(`Total`-`Lost`-`1st min`-`2nd min`-`3rd min`)/`Total`,
                    `Lost`=`Lost`/`Total`
                ), 
                .(`VariedX`, `VariedY`, `Submitted [minute]`)
            ],
            id.vars=c("VariedX", "VariedY", "Submitted [minute]"),
            variable.name="Outcome",
            value.name="Fraction"
        )[, .(
            `VariedX`, `VariedY`,
            `Submitted [minute]`, 
            `Outcome`=factor(`Outcome`,levels=c("Ledger in 1st min", "Ledger in 2nd min", "Ledger in 3rd min", "Ledger later","Lost")), 
            `Fraction [%]`=100*`Fraction`
        )],
    aes(x=`Submitted [minute]`, y=`Fraction [%]`, fill=`Outcome`)
) +
    geom_bar(stat="identity") +
    facet_varied() +
    scale_fill_manual(values=c(
        "Ledger in 1st min"=brewer.pal(n=5, name="Set1")[[2]], 
        "Ledger in 2nd min"=brewer.pal(n=5, name="Set1")[[3]], 
        "Ledger in 3rd min"=brewer.pal(n=5, name="Set1")[[4]], 
        "Ledger later"=brewer.pal(n=5, name="Set1")[[5]],
        "Lost"=brewer.pal(n=5, name="Set1")[[1]]
    )) +
    ggtitle("Transactions reaching the ledger", label) +
    theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
lifecycle[
    `Message` == "TX" & is.na(`To RB [s]`) & is.na(`In RB [s]`),
    .(`Throughput`, `Item`, `Created [s]`, `To EB [s]`)
] %>% head
# Out:
#   Throughput   Item  Created [s] To EB [s]
# 1 0.150 TxMB/s 23708 296         296.075
# 2 0.150 TxMB/s 23710 296         296.075
# 3 0.150 TxMB/s 23711 296         296.075
# 4 0.150 TxMB/s 23715 296         296.075
# 5 0.150 TxMB/s 23716 296         296.075
# 6 0.150 TxMB/s 23717 296         296.075

# %%
ggsave("plots/temporal-efficiency-bar.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Release memory

# %%
rm(lifecycle, outcomes, totals)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells  988152 52.8  2122312   113.4  2122312 113.4
# Vcells 1889058 14.5 74956810   571.9 93696012 714.9

# %% [markdown]
# ### Resource usage

# %%
if (file.exists("results/resources.Rdata")) {
    load(file="results/resources.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    resources <- fread("results/resources.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
    save(resources, file="results/resources.Rdata")
    cat(paste("Saved Rdata file: sampleSize =", sampleSize, "\n"))
}
resources %>% summary
resources[, `:=`(
    `VariedX`=factor(paste(`EB delay`, `Tx attack`, sep="\n"), levels=resources[,.N,.(`EB delay`,`Tx attack`)][order(-`EB delay`,-`Tx attack`)][,unique(paste(`EB delay`, `Tx attack`, sep="\n"))]),
    `VariedY`=factor(paste(`Propagation`, `Diffusion duration`, sep="\n"))
)]
# Out:
# Loaded Rdata file: sampleSize = 1
#  Simulator          Propagation          Network        Bandwidth
#  Rust:18000   eb-received :6000   topology-v2:18000   50 Mb/s:18000
#               fully-valid :6000
#               txs-received:6000
#
#
#
#
#           CPU               Diffusion duration         Voting duration
#  4 vCPU/node:18000   L_diff = 0 slots:9000     L_vote = 7 slots:18000
#                      L_diff = 7 slots:9000
#
#
#
#
#
#    Max EB size            Adversary                    EB delay
#  12 MB/EB:18000   33% adversary:18000   EB attack: 6.0 s/EB:9000
#                                         EB attack: none    :9000
#
#
#
#
#
#            Tx attack         Tx size             Throughput     Tx start [s]
#  Tx attack: 100%:9000   1500 B/Tx:18000   0.150 TxMB/s:18000   Min.   :60
#  Tx attack: none:9000                                          1st Qu.:60
#                                                                Median :60
#                                                                Mean   :60
#                                                                3rd Qu.:60
#                                                                Max.   :60
#
#   Tx stop [s]   Sim stop [s]        Node         Egress [B]
#  Min.   :960   Min.   :1200   node-0  :   24   Min.   :4.200e+03
#  1st Qu.:960   1st Qu.:1200   node-1  :   24   1st Qu.:1.032e+07
#  Median :960   Median :1200   node-10 :   24   Median :9.956e+07
#  Mean   :960   Mean   :1200   node-100:   24   Mean   :1.491e+08
#  3rd Qu.:960   3rd Qu.:1200   node-101:   24   3rd Qu.:1.978e+08
#  Max.   :960   Max.   :1200   node-102:   24   Max.   :1.685e+09
#                               (Other) :17856
#     Disk [B]       Total CPU [s]    Maximum CPU [s/s]
#  Min.   :      0   Min.   : 56.54   Min.   :1.450
#  1st Qu.:      0   1st Qu.: 86.20   1st Qu.:1.486
#  Median :      0   Median : 89.52   Median :1.611
#  Mean   :  15716   Mean   : 92.59   Mean   :2.140
#  3rd Qu.:      0   3rd Qu.: 98.10   3rd Qu.:2.628
#  Max.   :1041792   Max.   :114.89   Max.   :4.286

# %%
ggplot(
        resources[, .(`VariedX`, `VariedY`, `Node`, `Nodal egress [Mb/s]`=8*`Egress [B]`/simFinish/1e6)], 
    aes(x="", y=`Nodal egress [Mb/s]`)
) +
    geom_violin() +
    facet_varied(wide=FALSE) +
    xlab("") +
    ggtitle("Network", label)
# Out:
# plot without title

# %%
ggsave("plots/network.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
        resources[, .(`VariedX`, `VariedY`, `Node`, `1-Second peak CPU [vCPU⋅s/s]`=`Maximum CPU [s/s]`)], 
    aes(x="", y=`1-Second peak CPU [vCPU⋅s/s]`)
) +
    geom_boxplot() +
    ylim(0, NA) +
    facet_varied(wide=FALSE) +
    xlab("") +
    ggtitle("1-Second Peak CPU", label)
# Out:
# plot without title

# %%
ggsave("plots/cpu-peak.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
        resources[, .(`VariedX`, `VariedY`, `Node`, `Mean CPU [vCPU⋅s/s]`=`Total CPU [s]`/simFinish)], 
    aes(x="", y=`Mean CPU [vCPU⋅s/s]`)
) +
    geom_boxplot() +
    ylim(0, NA) +
    facet_varied(wide=FALSE) +
    xlab("") +
    ggtitle("Mean CPU", label)
# Out:
# plot without title

# %%
ggsave("plots/cpu-mean.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Release memory

# %%
rm(resources)

# %%
gc()
# Out:
#        used    (Mb) gc trigger (Mb)  max used (Mb)
# Ncells 1018191 54.4  2122312   113.4  2122312 113.4
# Vcells 1968958 15.1 59965448   457.6 93696012 714.9

# %% [markdown]
# ### Receipt of messages

# %% [markdown]
# #### Read results

# %%
if (file.exists("results/receipts.Rdata")) {
    load("results/receipts.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    receipts <- fread("results/receipts.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
    save(receipts, file="results/receipts.Rdata")
    cat(paste("Saved Rdata file: sampleSize =", sampleSize, "\n"))
}
setnames(receipts, old="Kind", new="Message")
receipts %>% summary
receipts[, `:=`(
    `VariedX`=factor(paste(`EB delay`, `Tx attack`, sep="\n"), levels=receipts[,.N,.(`EB delay`,`Tx attack`)][order(-`EB delay`,-`Tx attack`)][,unique(paste(`EB delay`, `Tx attack`, sep="\n"))]),
    `VariedY`=factor(paste(`Propagation`, `Diffusion duration`, sep="\n"))
)]
# Out:
# Loaded Rdata file: sampleSize = 0.15
#  Simulator              Propagation              Network
#  Rust:283098413   eb-received :93770806   topology-v2:283098413
#                   fully-valid :93856604
#                   txs-received:95471003
#
#
#
#
#    Bandwidth                  CPU                   Diffusion duration
#  50 Mb/s:283098413   4 vCPU/node:283098413   L_diff = 0 slots:140858252
#                                              L_diff = 7 slots:142240161
#
#
#
#
#
#          Voting duration        Max EB size                Adversary
#  L_vote = 7 slots:283098413   12 MB/EB:283098413   33% adversary:283098413
#
#
#
#
#
#
#                 EB delay                   Tx attack
#  EB attack: 6.0 s/EB:138324438   Tx attack: 100%:149456709
#  EB attack: none    :144773975   Tx attack: none:133641704
#
#
#
#
#
#       Tx size                 Throughput         Tx start [s]  Tx stop [s]
#  1500 B/Tx:283098413   0.150 TxMB/s:283098413   Min.   :60    Min.   :960
#                                                 1st Qu.:60    1st Qu.:960
#                                                 Median :60    Median :960
#                                                 Mean   :60    Mean   :960
#                                                 3rd Qu.:60    3rd Qu.:960
#                                                 Max.   :60    Max.   :960
#
#   Sim stop [s]  Message                  Item               Producer
#  Min.   :1200   EB:   142218   26-node-95  :     9791   node-528:  7412829
#  1st Qu.:1200   RB:   176732   54-node-525 :     9185   node-573:  4984065
#  Median :1200   TX:258494082   383-node-135:     8658   node-498:  3791877
#  Mean   :1200   VT: 24285381   296-node-99 :     8621   node-529:  3787504
#  3rd Qu.:1200                  100-node-432:     8588   node-101:  3784906
#  Max.   :1200                  177-node-149:     8525   node-475:  3781955
#                                (Other)     :283045045   (Other) :255555277
#  Generated [s]        Size [B]         Recipient          Received [s]
#  Min.   :  20.07   Min.   :   105   node-98 :   379688   Min.   :  20.1
#  1st Qu.: 296.00   1st Qu.:  1500   node-334:   379667   1st Qu.: 296.1
#  Median : 536.17   Median :  1500   node-414:   379551   Median : 536.4
#  Mean   : 521.67   Mean   :  1498   node-658:   379288   Mean   : 522.4
#  3rd Qu.: 743.00   3rd Qu.:  1500   node-149:   379242   3rd Qu.: 746.6
#  Max.   :1198.00   Max.   :256240   node-666:   379168   Max.   :1200.0
#                                     (Other) :280821809
#   Elapsed [s]
#  Min.   : 0.0000
#  1st Qu.: 0.0941
#  Median : 0.1527
#  Mean   : 0.7350
#  3rd Qu.: 0.5117
#  Max.   :10.2188

# %%
kinds <- receipts[, unique(`Message`) %>% sort]
kinds
# Out:
# [1] EB RB TX VT
# Levels: EB RB TX VT

# %% [markdown]
# #### Arrival histograms

# %% [markdown]
# ##### Compare the distributions of elapsed times

# %%
arrivalDelayHistogram <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
            rs[, .(`VariedX`, `VariedY`, `Network`, `Elapsed [s]`, `Minute created`=factor(floor(`Generated [s]`/60)))],
        aes(x=`Elapsed [s]`, fill=`Minute created`)
    ) +
        geom_histogram(binwidth=0.1) +
        facet_varied(scales=scales) +
        xlab("Time from generation to receipt at node [s]") +
        ylab("Number received") +
        ggtitle(title, subtitle=label) +
        theme(axis.text.y = element_blank(), axis.ticks.y = element_blank())
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
for (k in kinds)
    arrivalDelayHistogram(
        receipts[`Message` == k],
        paste("Arrival delay for", k),
        scales="fixed",
        outfiles=paste0("plots/elapsed-", k, ".png")
    ) %>% print
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# #### Bandwidth usage

# %% [markdown]
# ##### Total network bandwidth

# %%
totalBandwidthPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
            rs[,
                .(`Size [Gb]`=8*sum(`Size [B]`, rm.na=TRUE)/1e9/sampleSize),
                by=.(`VariedX`, `VariedY`, `Network`, `Slot`=floor(`Received [s]`), `Message`)
            ],
        aes(x=`Slot`, y=`Size [Gb]`, fill=`Message`)
    ) +
        geom_area() +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Total network ingress [Gb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
totalBandwidthPlot(
    receipts,
    "Total bandwidth",
    scales="fixed",
    outfiles=paste0("plots/ingress-total-area.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Bandwidth usage per node

# %%
nodeCount <- receipts[, length(unique(`Recipient`))]
nodeCount
# Out:
# [1] 750

# %%
meanNodalIngressPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
            rs[,
                .(`Size [Mb/node]`=8*sum(`Size [B]`)/1e6/ifelse(`Network`=="topology-v1",10000,750)/sampleSize),
                by=.(`VariedX`, `VariedY`, `Network`, `Slot`=floor(`Received [s]`), `Message`)
            ],
        aes(x=`Slot`, y=`Size [Mb/node]`, fill=`Message`)
    ) +
        geom_area() +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Mean network ingress among nodes [Mb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanNodalIngressPlot(
    receipts, 
    "Mean nodal ingress",
    scales="fixed",
    outfiles=paste0("plots/ingress-average-area.png")
)
# Out:
# plot without title

# %%
peakNodalIngressPlot <- function(rs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
            rs[,
                .(`Size [Mb]`=8*sum(`Size [B]`, rm.na=TRUE)/1e6/sampleSize),
                by=.(`VariedX`, `VariedY`, `Network`, `Slot`=floor(`Received [s]`), `Message`, `Recipient`)
            ][,
                .(`Size [Mb]`=max(`Size [Mb]`)),
                by=.(`VariedX`, `VariedY`, `Network`, `Slot`, `Message`)
            ],
        aes(x=`Slot`, y=`Size [Mb]`, color=`Message`)
    ) +
        geom_point(size=0.5) +
        facet_varied(scales=scales) +
        xlab("Slot [s]") +
        ylab("Maximum network ingress among nodes [Mb/s]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakNodalIngressPlot(
    receipts, 
    "Peak nodal ingress",
    outfiles=paste0("plots/ingress-peak-point.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Release memory

# %%
rm(receipts)

# %%
gc()
# Out:
#        used       (Mb)    gc trigger  (Mb)     max used    (Mb)
# Ncells    1163625    62.2     3253629    173.8     3253629    173.8
# Vcells 4248983027 32417.2 13695463428 104488.1 17119329284 130610.2

# %% [markdown]
# ### CPU usage

# %% [markdown]
# #### Read results

# %%
if (file.exists("results/cpus.Rdata")) {
    load(file="results/cpus.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    cpus <- fread("results/cpus.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
    save(cpus, file="results/cpus.Rdata")
    cat(paste("Saved Rdata file: sampleSize =", sampleSize, "\n"))
}
cpus %>% summary
cpus[, `:=`(
    `VariedX`=factor(paste(`EB delay`, `Tx attack`, sep="\n"), levels=cpus[,.N,.(`EB delay`,`Tx attack`)][order(-`EB delay`,-`Tx attack`)][,unique(paste(`EB delay`, `Tx attack`, sep="\n"))]),
    `VariedY`=factor(paste(`Propagation`, `Diffusion duration`, sep="\n"))
)]
# Out:
# Loaded Rdata file: sampleSize = 0.15
#  Simulator              Propagation              Network
#  Rust:281648398   eb-received :93287252   topology-v2:281648398
#                   fully-valid :93371334
#                   txs-received:94989812
#
#
#
#
#    Bandwidth                  CPU                   Diffusion duration
#  50 Mb/s:281648398   4 vCPU/node:281648398   L_diff = 0 slots:140169852
#                                              L_diff = 7 slots:141478546
#
#
#
#
#
#          Voting duration        Max EB size                Adversary
#  L_vote = 7 slots:281648398   12 MB/EB:281648398   33% adversary:281648398
#
#
#
#
#
#
#                 EB delay                   Tx attack
#  EB attack: 6.0 s/EB:136712677   Tx attack: 100%:147850313
#  EB attack: none    :144935721   Tx attack: none:133798085
#
#
#
#
#
#       Tx size                 Throughput         Tx start [s]  Tx stop [s]
#  1500 B/Tx:281648398   0.150 TxMB/s:281648398   Min.   :60    Min.   :960
#                                                 1st Qu.:60    1st Qu.:960
#                                                 Median :60    Median :960
#                                                 Mean   :60    Mean   :960
#                                                 3rd Qu.:60    3rd Qu.:960
#                                                 Max.   :60    Max.   :960
#
#   Sim stop [s]       Slot              Node                Task
#  Min.   :1200   Min.   :  20.0   node-574:   379919   ValTX  :256745331
#  1st Qu.:1200   1st Qu.: 296.0   node-429:   379893   ValVote: 24271722
#  Median :1200   Median : 535.0   node-15 :   379576   ValRB  :   175571
#  Mean   :1200   Mean   : 521.9   node-69 :   379560   ValRH  :   142212
#  3rd Qu.:1200   3rd Qu.: 747.0   node-425:   379551   ValEH  :   141018
#  Max.   :1200   Max.   :1199.0   node-511:   379543   ValEB  :   139827
#                                  (Other) :279370356   (Other):    32717
#   Duration [s]
#  Min.   :0.0001481
#  1st Qu.:0.0004284
#  Median :0.0004284
#  Mean   :0.0008884
#  3rd Qu.:0.0004284
#  Max.   :1.3681481

# %%
cpusNode <-
        cpus[
            ,
            .(`Duration [s]`=sum(`Duration [s]`)),
            by=.(`VariedX`, `VariedY`, `Network`, `Node`, `Slot`)
        ]

# %%
nodeCount <- cpusNode[, length(unique(`Node`))]
nodeCount
# Out:
# [1] 750

# %% [markdown]
# #### Peak CPU usage

# %% [markdown]
# ##### Histogram

# %%
peakCpuHistogram <- function(cs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
            cs[,
                .(`Duration [%]`=100*max(`Duration [s]`)),
                by=.(`VariedX`, `VariedY`, `Network`, `Slot`)
            ], 
        aes(x=`Duration [%]`)
    ) +
        geom_histogram(binwidth=10) +
        facet_varied(scales=scales) +
        xlab("Peak CPU load [%]") +
        ylab("Number of slots") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakCpuHistogram(
    cpusNode, 
    "Peak CPU load among all nodes",
    scales="fixed",
    outfiles=paste0("plots/cpu-peak-histogram.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Time series

# %%
peakCpuTimeseries <- function(cs, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
            cs[,
                .(`Duration [%]`=100*mean(`Duration [s]`)/sampleSize),
                by=.(`VariedX`, `VariedY`, `Network`, `Slot`)
            ], 
        aes(x=`Slot`, y=`Duration [%]`)) +
        geom_line() +
        facet_varied(scale=scales) +
        xlab("Slot") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
peakCpuTimeseries(
    cpusNode,
    "Mean CPU load among all nodes",
    outfiles=paste0("plots/cpu-peak-timeseries.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Mean CPU usage

# %% [markdown]
# ##### Histogram

# %%
meanCpuHistogram <- function(cs, nodeSeconds, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
            cs[,
                .(`Duration [%]`=100*sum(`Duration [s]`)/nodeSeconds/ifelse(`Network` == "topology-v1", 10000, 750)),
                by=.(`VariedX`, `VariedY`, `Network`, `Task`)
            ], 
        aes(x="", fill=`Task`, y=`Duration [%]`)) +
        geom_bar(stat = "identity") +
        facet_varied(wide=FALSE, scales=scales) +
        xlab("") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanCpuHistogram(
    cpus[`Slot` >= txFirst & `Slot` < txLast],
    txWindow * sampleSize, 
    "Mean CPU load among all nodes", 
    scales="fixed",
    outfiles=paste0("plots/cpu-mean-histogram.png")
)
# Out:
# plot without title

# %% [markdown]
# ##### Time series

# %%
meanCpuTimeseries <- function(cs, nodeSeconds, title="", scales="fixed", outfiles=c(), width=16, height=8, dpi=150) {
    g <- ggplot(
            cs[,
                .(`Duration [%]`=100*sum(`Duration [s]`)/nodeSeconds/ifelse(`Network`=="topology-v1",10000,750)/sampleSize),
                by=.(`VariedX`, `VariedY`, `Network`, `Slot`, `Task`)
            ], 
        aes(x=`Slot`, y=`Duration [%]`, color=`Task`)
    ) +
        geom_point(size=0.25, alpha=0.75) +
        facet_varied(scales=scales) +
        scale_y_sqrt() +
        xlab("Slot") +
        ylab("Mean CPU load [%]") +
        ggtitle(title, subtitle=label)
    for (outfile in outfiles)
        ggsave(outfile, units="in", width=width, height=height, dpi=dpi)
    g
}

# %%
meanCpuTimeseries(
    cpus, 
    sampleSize, 
    "Mean CPU load among all nodes",
    outfiles=paste0("plots/cpu-mean-timeseries.png")
)
# Out:
# plot without title

# %% [markdown]
# #### Release memory

# %%
rm(cpus, cpusNode)

# %%
gc()
# Out:
#        used       (Mb)    gc trigger  (Mb)    max used    (Mb)
# Ncells    1037694    55.5     3253629   173.8     3253629    173.8
# Vcells 3241206590 24728.5 10956370743 83590.5 17119329284 130610.2

# %% [markdown]
# ### Block contents

# %% [markdown]
# ### Read data

# %%
if (file.exists("results/sizes.Rdata")) {
    load(file="results/sizes.Rdata")
    cat(paste("Loaded Rdata file: sampleSize =", sampleSize, "\n"))
} else {
    sizes <- fread("results/sizes.csv.gz", stringsAsFactors=TRUE)
    sampleSize <- 1
    save(sizes, file="results/sizes.Rdata")
    cat(paste("Saved Rdata file: sampleSize =", sampleSize, "\n"))
}
setnames(sizes, old="Kind", new="Message")
sizes %>% summary
sizes[, `:=`(
    `VariedX`=factor(paste(`EB delay`, `Tx attack`, sep="\n"), levels=sizes[,.N,.(`EB delay`,`Tx attack`)][order(-`EB delay`,-`Tx attack`)][,unique(paste(`EB delay`, `Tx attack`, sep="\n"))]),
    `VariedY`=factor(paste(`Propagation`, `Diffusion duration`, sep="\n"))
)]
# Out:
# Loaded Rdata file: sampleSize = 1
#  Simulator         Propagation         Network       Bandwidth
#  Rust:2530   eb-received :840   topology-v2:2530   50 Mb/s:2530
#              fully-valid :828
#              txs-received:862
#
#
#
#
#           CPU              Diffusion duration         Voting duration
#  4 vCPU/node:2530   L_diff = 0 slots:1266     L_vote = 7 slots:2530
#                     L_diff = 7 slots:1264
#
#
#
#
#
#    Max EB size           Adversary                   EB delay
#  12 MB/EB:2530   33% adversary:2530   EB attack: 6.0 s/EB:1236
#                                       EB attack: none    :1294
#
#
#
#
#
#            Tx attack         Tx size            Throughput    Tx start [s]
#  Tx attack: 100%:1266   1500 B/Tx:2530   0.150 TxMB/s:2530   Min.   :60
#  Tx attack: none:1264                                        1st Qu.:60
#                                                              Median :60
#                                                              Mean   :60
#                                                              3rd Qu.:60
#                                                              Max.   :60
#
#   Tx stop [s]   Sim stop [s]  Message             Item      Generated [s]
#  Min.   :960   Min.   :1200   EB:1265   100-node-432:  48   Min.   :  20.07
#  1st Qu.:960   1st Qu.:1200   RB:1265   105-node-598:  48   1st Qu.: 383.07
#  Median :960   Median :1200             131-node-573:  48   Median : 608.08
#  Mean   :960   Mean   :1200             177-node-149:  48   Mean   : 603.56
#  3rd Qu.:960   3rd Qu.:1200             20-node-220 :  48   3rd Qu.: 864.08
#  Max.   :960   Max.   :1200             219-node-475:  48   Max.   :1195.08
#                                         (Other)     :2242
#   Transactions          Endorses
#  Min.   :   0   105-node-598:  24
#  1st Qu.:  60   177-node-149:  24
#  Median :  60   26-node-95  :  24
#  Mean   :2355   393-node-424:  24
#  3rd Qu.:5081   839-node-148:  22
#  Max.   :8000   (Other)     : 643
#                 NA's        :1769

# %%
txSize <- sizes[, as.numeric(sub(" .*$", "", unique(`Tx size`)))]
txSize
# Out:
# [1] 1500

# %% [markdown]
# ### EB contents

# %% [markdown]
# #### Transactions

# %%
ggplot(sizes[`Message` == "EB"], aes(x=`Transactions`)) +
    geom_histogram(binwidth=1000) +
    facet_varied() +
    ylab("Number of EBs") +
    ggtitle("Number of transactions in EBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-ebs-txs.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
        sizes[`Message` == "EB", .(`EB size [MB]`=`Transactions`*txSize/1e6), .(`VariedX`, `VariedY`, `Network`)], 
    aes(x=`EB size [MB]`)
) +
    geom_histogram(binwidth=1) +
    facet_varied() +
    ylab("Number of EBs") +
    ggtitle("Size of transactions in EBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-ebs-size.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# ### RB contents

# %% [markdown]
# #### Transactions

# %%
ggplot(sizes[`Message` == "RB"], aes(x=`Transactions`)) +
    geom_histogram(binwidth=10) +
    facet_varied() +
    ylab("Number of RBs") +
    ggtitle("Number of transactions in RBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-rbs-txs.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
        sizes[`Message` == "RB", .(`RB size [kB]`=`Transactions`*txSize/1e3), .(`VariedX`, `VariedY`)],
    aes(x=`RB size [kB]`)
) +
    geom_histogram(binwidth=10) +
    facet_varied() +
    ylab("Number of RBs") +
    ggtitle("Size of transactions in RBs", label)
# Out:
# plot without title

# %%
ggsave("plots/contents-rbs-size.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# ### Disposition of blocks

# %% [markdown]
# #### Data processing

# %%
ebSizes <- 
        sizes[`Message` == "RB" & !is.na(`Endorses`), .(`Certified`=TRUE), .(`VariedX`, `VariedY`, `Item`=`Endorses`)][
        sizes[`Message` == "EB", .(`EB Transactions`=`Transactions`), .(`VariedX`, `VariedY`, `Item`)], 
            on=c("VariedX", "VariedY", "Item")
        ][
            ,
            .(
                `EB txs later not certified`=ifelse(is.na(`Certified`), as.numeric(`EB Transactions`), 0),
                `EB txs later certified`=ifelse(is.na(`Certified`), 0, as.numeric(`EB Transactions`))
            ),
            .(`VariedX`, `VariedY`, `Item`)
        ]

# %%
rbSizes <- 
        ebSizes[
            ebSizes[, .(`EB txs certified now`=`EB txs later certified`), .(`VariedX`, `VariedY`, `Endorses`=`Item`)][
                sizes[`Message` == "RB", .(`Generated [s]`, `RB Transactions`=as.numeric(`Transactions`)), .(`VariedX`, `VariedY`, `Item`, `Endorses`)],
                on=c("VariedX", "VariedY", "Endorses")
            ],
            on=c("VariedX", "VariedY", "Item")
        ][
            ,
            .(
                `Generated [s]`,
                `RB`=`RB Transactions`,
                `EB later not certified`=`EB txs later not certified`,
                `EB later certified`=`EB txs later certified`,
                `EB now certified`=ifelse(is.na(`EB txs certified now`), 0, `EB txs certified now`)
            ),
            , .(`VariedX`, `VariedY`, `Item`)
        ]

# %%
blocks <- melt(
    rbSizes, 
    id.vars=c("VariedX", "VariedY", "Item", "Generated [s]"),
    measure.vars=c("RB", "EB later not certified", "EB later certified", "EB now certified"),
    variable.name="Block",
    value.name="Transactions"
)

# %% [markdown]
# #### Sanity checks

# %%
ebSizes[, .N] == sizes[`Message` == "EB", .N]
# Out:
# [1] TRUE

# %%
ebSizes[, sum(`EB txs later not certified`) + sum(`EB txs later certified`)] == sizes[`Message` == "EB", sum(`Transactions`)]
# Out:
# [1] TRUE

# %%
rbSizes[, .N] == sizes[`Message` == "RB", .N]
# Out:
# [1] TRUE

# %%
rbSizes[, sum(`RB`)] == sizes[`Message` == "RB", sum(`Transactions`)]
# Out:
# [1] TRUE

# %%
rbSizes[, sum(`EB later not certified`) + sum(`EB later certified`)] == sizes[`Message` == "EB", sum(`Transactions`)]
# Out:
# [1] TRUE

# %%
# TODO: Compute precise equality that accounts for forks.
rbSizes[, sum(`EB later certified`)] <= rbSizes[, sum(`EB now certified`)]
# Out:
# [1] TRUE

# %% [markdown]
# #### Transactions

# %%
ggplot(
        blocks[, .(`Transactions`=sum(`Transactions`)), .(`VariedX`, `VariedY`, `Block`, `Minute generated`=(floor(`Generated [s]`/60)))],
    aes(x=`Minute generated`, y=`Transactions`, fill=`Block`)
) +
    geom_bar(stat="identity") +
    facet_varied()
# Out:
# plot without title

# %%
ggsave("plots/disposition-txs-timeseries.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
        blocks[, .(`Transactions`=sum(`Transactions`)), .(`VariedX`, `VariedY`, `Block`)],
    aes(x="", y=`Transactions`, fill=`Block`)
) +
    geom_bar(stat="identity") +
    facet_varied()
# Out:
# plot without title

# %%
ggsave("plots/disposition-txs-histogram.png", units="in", dpi=150, width=16, height=8)

# %% [markdown]
# #### Sizes

# %%
ggplot(
        blocks[, .(`Total size of transactions [MB]`=sum(`Transactions`)*txSize/1e6), .(`VariedX`, `VariedY`, `Block`, `Minute of block generation`=(floor(`Generated [s]`/60)))], 
    aes(x=`Minute of block generation`, y=`Total size of transactions [MB]`, fill=`Block`)
) +
    geom_bar(stat="identity") +
    facet_varied() +
    ggtitle("Disposition of transactions in blocks", label)
# Out:
# plot without title

# %%
ggsave("plots/disposition-size-timeseries.png", units="in", dpi=150, width=16, height=8)

# %%
ggplot(
        blocks[, .(`Total size of transactions [MB]`=sum(`Transactions`)*txSize/1e6), .(`VariedX`, `VariedY`, `Block`)], 
    aes(x="", y=`Total size of transactions [MB]`, fill=`Block`)
) +
    geom_bar(stat="identity") +
    facet_varied() +
    ggtitle("Disposition of transactions", label)
# Out:
# plot without title

# %%
ggsave("plots/disposition-size-histogram.png", units="in", dpi=150, width=16, height=8)
